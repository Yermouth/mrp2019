# %%
try:
    __IPYTHON__
    USING_IPYTHON = True
except NameError:
    USING_IPYTHON = False

# %% [markdown]
# #### Argparse

# %%
import argparse
ap = argparse.ArgumentParser()
ap.add_argument('mrp_data_dir', help='')
ap.add_argument('--train-sub-dir', default='training', help='')
ap.add_argument('--companion-sub-dir', default='./mrp-companion/2019/companion')
ap.add_argument('--mrp-file-extension', default='.mrp')
ap.add_argument('--companion-file-extension', default='.conllu')
ap.add_argument('--graphviz-file-template', default='http://localhost:8000/files/proj29_ds1/home/slai/mrp/graphviz/{}/{}.mrp/{}.png')
arg_string = """
    ./data/
"""
arguments = [arg for arg_line in arg_string.split(r'\\n') for arg in arg_line.split()]

# %%
if USING_IPYTHON:
    args = ap.parse_args(arguments)
else:
    args = ap.parse_args()

# %%
args
# Out:
# Namespace(companion_file_extension='.conllu', companion_sub_dir='./mrp-companion/2019/companion', graphviz_file_template='http://localhost:8000/files/proj29_ds1/home/slai/mrp/graphviz/{}/{}.mrp/{}.png', mrp_data_dir='./data/', mrp_file_extension='.mrp', train_sub_dir='training')

# %% [markdown]
# #### Library imports

# %%
import json
import logging
import os
import pprint
import string

from collections import Counter
from collections import defaultdict
from tqdm import tqdm
import matplotlib.pyplot as plt
import networkx as nx
import numpy as np

# %% [markdown]
# #### ipython notebook specific imports

# %%
if USING_IPYTHON:
    # matplotlib config
    # %matplotlib inline

# %%
logging.basicConfig(level=logging.INFO, handlers=[logging.StreamHandler()])
logger = logging.getLogger(__name__)  # pylint: disable=invalid-name
logger.setLevel(logging.INFO)

# %% [markdown]
# ### Constants

# %%
UNKWOWN = 'UNKWOWN'

# %% [markdown]
# ### Load data

# %%
train_dir = os.path.join(args.mrp_data_dir, args.train_sub_dir)
frameworks = [sub_dir for sub_dir in os.listdir(train_dir) if os.path.isdir(os.path.join(train_dir, sub_dir))]
frameworks
# Out:
# ['ucca', 'psd', 'eds', 'dm', 'amr']

# %%
framework2dataset2mrp_jsons = {}
for framework in tqdm(frameworks, desc='frameworks'):
    dataset2mrp_jsons = {}
    framework_dir = os.path.join(train_dir, framework)
    dataset_names = os.listdir(framework_dir)
    
    for dataset_name in tqdm(dataset_names, desc='dataset_name'):
        mrp_jsons = []
        if not dataset_name.endswith(args.mrp_file_extension):
            continue
        with open(os.path.join(framework_dir, dataset_name)) as rf:
            for line in rf:
                mrp_json = json.loads(line.strip())
                if framework == 'ucca' and 'nodes' in mrp_json and 'input' in mrp_json:
                    input_text = mrp_json['input']
                    nodes = mrp_json['nodes']
                    for i, node in enumerate(nodes):
                        if 'anchors' not in node:
                            continue
                        text_segments = []
                        for anchor in node['anchors']:
                            text_segments.append(input_text[anchor.get('from', -1): anchor.get('to', -1)])
                        mrp_json['nodes'][i]['label'] = ''.join(text_segments)
                        
                mrp_jsons.append(mrp_json)
        dataset_name = dataset_name.split('.')[0]
        dataset2mrp_jsons[dataset_name] = mrp_jsons
                
    framework2dataset2mrp_jsons[framework] = dataset2mrp_jsons
# Out:
# frameworks:   0%|          | 0/5 [00:00<?, ?it/s]
# dataset_name:   0%|          | 0/2 [00:00<?, ?it/s]
# dataset_name:  50%|█████     | 1/2 [00:00<00:00,  2.99it/s]
# frameworks:  20%|██        | 1/5 [00:00<00:03,  1.23it/s]s]
# dataset_name:   0%|          | 0/1 [00:00<?, ?it/s]
# frameworks:  40%|████      | 2/5 [00:04<00:05,  1.76s/it]t]
# dataset_name:   0%|          | 0/1 [00:00<?, ?it/s]
# frameworks:  60%|██████    | 3/5 [00:09<00:05,  2.77s/it]t]
# dataset_name:   0%|          | 0/1 [00:00<?, ?it/s]
# frameworks:  80%|████████  | 4/5 [00:15<00:03,  3.65s/it]t]
# dataset_name:   0%|          | 0/14 [00:00<?, ?it/s]
# dataset_name:  43%|████▎     | 6/14 [00:00<00:00, 21.00it/s]
# dataset_name:  57%|█████▋    | 8/14 [00:00<00:00, 17.69it/s]
# dataset_name:  71%|███████▏  | 10/14 [00:01<00:00,  6.14it/s]
# dataset_name:  79%|███████▊  | 11/14 [00:01<00:00,  5.44it/s]
# frameworks: 100%|██████████| 5/5 [00:17<00:00,  3.03s/it]t/s]

# %%
for framework in framework2dataset2mrp_jsons:
    logger.info(framework)
    logger.info(list(framework2dataset2mrp_jsons[framework].keys()))
# Out:
# INFO:__main__:ucca
# INFO:__main__:['wiki', 'ewt']
# INFO:__main__:psd
# INFO:__main__:['wsj']
# INFO:__main__:eds
# INFO:__main__:['wsj']
# INFO:__main__:dm
# INFO:__main__:['wsj']
# INFO:__main__:amr
# INFO:__main__:['xinhua', 'wsj', 'wiki', 'wb', 'rte', 'proxy', 'mt09sdl', 'lorelei', 'fables', 'dfb', 'dfa', 'cctv', 'bolt', 'amr-guidelines']

# %% [markdown]
# ### Data Preprocessing companion

# %%
dataset2cid2parse = {}
for framework in os.listdir(args.companion_sub_dir):
    framework_dir = os.path.join(args.companion_sub_dir, framework)
    if not os.path.isdir(framework_dir):
        continue
    for dataset in tqdm(os.listdir(framework_dir), desc='dataset'):
        if not dataset.endswith(args.companion_file_extension):
            continue
        dataset_name = dataset.split('.')[0].rstrip(string.digits)
        cid2parse = {}
        with open(os.path.join(framework_dir, dataset)) as rf:
            parse = []
            for line in rf:
                line = line.strip()
                if not line:
                    cid2parse[cid] = parse
                    parse = []
                    cid = ''
                elif line.startswith('#'):
                    cid = line[1:]
                else:
                    parse.append(line.split('\t'))
        dataset2cid2parse[dataset_name] = cid2parse
# Out:
# dataset: 100%|██████████| 13/13 [00:03<00:00,  3.36it/s]
# dataset: 100%|██████████| 5/5 [00:01<00:00,  3.57it/s]
# dataset: 100%|██████████| 6/6 [00:00<00:00, 30.49it/s]

# %%
dataset2cid2parse.keys()
# Out:
# dict_keys(['amr-guidelines', 'bolt', 'cctv', 'dfa', 'dfb', 'fables', 'lorelei', 'mt09sdl', 'proxy', 'rte', 'wb', 'wiki', 'xinhua', 'wsj', 'ewt'])

# %%
dataset = 'xinhua'
framework = 'amr'
dataset2cid2parse[dataset][framework2dataset2mrp_jsons[framework][dataset][1]['id']]
# Out:
# [['1',
#   'According',
#   'accord',
#   'VERB',
#   'VBG',
#   '_',
#   '10',
#   'case',
#   '_',
#   'TokenRange=0:9'],
#  ['2', 'to', 'to', 'ADP', 'TO', '_', '1', 'fixed', '_', 'TokenRange=10:12'],
#  ['3',
#   'Taiwan',
#   'Taiwan',
#   'PROPN',
#   'NNP',
#   '_',
#   '10',
#   'nmod:poss',
#   '_',
#   'TokenRange=13:19'],
#  ['4', '’s', '’s', 'PART', 'POS', '_', '3', 'case', '_', 'TokenRange=20:22'],
#  ['5', '“', '“', 'PUNCT', '``', '_', '10', 'punct', '_', 'TokenRange=23:24'],
#  ['6',
#   'Ministry',
#   'Ministry',
#   'PROPN',
#   'NNP',
#   '_',
#   '10',
#   'dep',
#   '_',
#   'TokenRange=25:33'],
#  ['7', 'of', 'of', 'ADP', 'IN', '_', '8', 'case', '_', 'TokenRange=34:36'],
#  ['8',
#   'Economy',
#   'Economy',
#   'PROPN',
#   'NNP',
#   '_',
#   '6',
#   'obl',
#   '_',
#   'TokenRange=37:44'],
#  ['9', '“', '“', 'PUNCT', '``', '_', '10', 'punct', '_', 'TokenRange=45:46'],
#  ['10',
#   'statistics',
#   'statistics',
#   'NOUN',
#   'NNS',
#   '_',
#   '26',
#   'obl',
#   '_',
#   'TokenRange=47:57'],
#  ['11', ',', ',', 'PUNCT', ',', '_', '26', 'punct', '_', 'TokenRange=58:59'],
#  ['12', 'the', 'the', 'DET', 'DT', '_', '13', 'det', '_', 'TokenRange=60:63'],
#  ['13',
#   'volume',
#   'volume',
#   'NOUN',
#   'NN',
#   '_',
#   '26',
#   'nsubj',
#   '_',
#   'TokenRange=64:70'],
#  ['14', 'of', 'of', 'ADP', 'IN', '_', '15', 'case', '_', 'TokenRange=71:73'],
#  ['15',
#   'trade',
#   'trade',
#   'NOUN',
#   'NN',
#   '_',
#   '13',
#   'nmod',
#   '_',
#   'TokenRange=74:79'],
#  ['16',
#   'between',
#   'between',
#   'ADP',
#   'IN',
#   '_',
#   '17',
#   'case',
#   '_',
#   'TokenRange=80:87'],
#  ['17',
#   'mainland',
#   'mainland',
#   'NOUN',
#   'NN',
#   '_',
#   '15',
#   'nmod',
#   '_',
#   'TokenRange=88:96'],
#  ['18', 'and', 'and', 'CONJ', 'CC', '_', '19', 'cc', '_', 'TokenRange=97:100'],
#  ['19',
#   'Taiwan',
#   'Taiwan',
#   'PROPN',
#   'NNP',
#   '_',
#   '17',
#   'conj',
#   '_',
#   'TokenRange=101:107'],
#  ['20',
#   'last',
#   'last',
#   'ADJ',
#   'JJ',
#   '_',
#   '21',
#   'amod',
#   '_',
#   'TokenRange=108:112'],
#  ['21',
#   'year',
#   'year',
#   'NOUN',
#   'NN',
#   '_',
#   '26',
#   'obl:tmod',
#   '_',
#   'TokenRange=113:117'],
#  ['22',
#   'was',
#   'be',
#   'VERB',
#   'VBD',
#   '_',
#   '26',
#   'cop',
#   '_',
#   'TokenRange=118:121'],
#  ['23',
#   '20.9',
#   '20.9',
#   'NUM',
#   'CD',
#   '_',
#   '24',
#   'compound',
#   '_',
#   'TokenRange=122:126'],
#  ['24',
#   'billion',
#   'billion',
#   'NUM',
#   'CD',
#   '_',
#   '26',
#   'nummod',
#   '_',
#   'TokenRange=127:134'],
#  ['25',
#   'US',
#   'US',
#   'PROPN',
#   'NNP',
#   '_',
#   '26',
#   'compound',
#   '_',
#   'TokenRange=135:137'],
#  ['26',
#   'dollars',
#   'dollar',
#   'NOUN',
#   'NNS',
#   '_',
#   '0',
#   'root',
#   '_',
#   'TokenRange=138:145'],
#  ['27', '.', '.', 'PUNCT', '.', '_', '26', 'punct', '_', 'TokenRange=146:147']]

# %%
framework2dataset2mrp_jsons[framework][dataset][1]
# Out:
# {'id': 'nw.chtb_0012.2',
#  'flavor': 2,
#  'framework': 'amr',
#  'version': 0.9,
#  'time': '2019-04-10 (20:11)',
#  'input': 'According to Taiwan \'s " Ministry of Economy " statistics , the volume of trade between mainland and Taiwan last year was 20.9 billion US dollars .',
#  'tops': [0],
#  'nodes': [{'id': 0, 'label': 'say-01'},
#   {'id': 1, 'label': 'statistic'},
#   {'id': 2, 'label': 'government-organization'},
#   {'id': 3,
#    'label': 'name',
#    'properties': ['op1', 'op2', 'op3'],
#    'values': ['Ministry', 'of', 'Economy']},
#   {'id': 4,
#    'label': 'monetary-quantity',
#    'properties': ['quant'],
#    'values': ['20900000000']},
#   {'id': 5, 'label': 'dollar'},
#   {'id': 6, 'label': 'country'},
#   {'id': 7, 'label': 'name', 'properties': ['op1'], 'values': ['US']},
#   {'id': 8, 'label': 'volume'},
#   {'id': 9, 'label': 'trade-01'},
#   {'id': 10, 'label': 'mainland'},
#   {'id': 11, 'label': 'country'},
#   {'id': 12, 'label': 'name', 'properties': ['op1'], 'values': ['Taiwan']},
#   {'id': 13, 'label': 'year'},
#   {'id': 14, 'label': 'last'}],
#  'edges': [{'source': 1, 'target': 2, 'label': 'source'},
#   {'source': 11, 'target': 12, 'label': 'name'},
#   {'source': 2, 'target': 3, 'label': 'name'},
#   {'source': 13, 'target': 14, 'label': 'mod', 'normal': 'domain'},
#   {'source': 9, 'target': 10, 'label': 'ARG0'},
#   {'source': 4, 'target': 5, 'label': 'unit'},
#   {'source': 0, 'target': 4, 'label': 'ARG1'},
#   {'source': 5, 'target': 6, 'label': 'mod', 'normal': 'domain'},
#   {'source': 6, 'target': 7, 'label': 'name'},
#   {'source': 8, 'target': 13, 'label': 'time'},
#   {'source': 0, 'target': 1, 'label': 'ARG0'},
#   {'source': 2, 'target': 11, 'label': 'poss'},
#   {'source': 8, 'target': 9, 'label': 'quant-of', 'normal': 'quant'},
#   {'source': 4, 'target': 8, 'label': 'domain'},
#   {'source': 9, 'target': 11, 'label': 'ARG2'}]}

# %% [markdown]
# ### Companion statistics

# %%
list(dataset2cid2parse['wsj'].keys())[:10]
# Out:
# ['20988006',
#  '20988012',
#  '20949001',
#  '20949006',
#  '20984005',
#  '20984010',
#  '20984015',
#  '20984021',
#  '20984026',
#  '20984033']

# %%
verb_lemma2org2dataset_cids = defaultdict(lambda: defaultdict(list))
for dataset, cid2parse in dataset2cid2parse.items():
    for cid, parse in cid2parse.items():
        for word_record in parse:
            word_index, org, lemma, pos, *_ = word_record
            if pos == 'VERB':
                verb_lemma2org2dataset_cids[lemma][org].append((dataset, cid))

# %%
logger.info('No. of unique verb lemma: {}'.format(len(verb_lemma2org2dataset_cids)))
# Out:
# INFO:__main__:No. of unique verb lemma: 4928

# %%
for verb_lemma, org2dataset_cids in verb_lemma2org2dataset_cids.items():
    sorted_org_count = sorted([
        (org, len(dataset_cids)) 
        for org, dataset_cids in org2dataset_cids.items()
    ], key=lambda x: x[1], reverse=True)
    print(verb_lemma, sorted_org_count[:10])
# Out:
# be [('is', 6239), ('was', 2727), ('are', 2308), ('be', 1888), ('’s', 1619), ('were', 901), ('been', 557), ('’re', 217), ('’m', 215), ('being', 205)]
# bear [('born', 145), ('bear', 39), ('bore', 9), ('bearing', 7), ('Born', 7), ('bears', 5), ('Bearing', 4), ('Bear', 1)]
# go [('going', 941), ('go', 876), ('went', 360), ('goes', 192), ('gone', 124), ('Go', 44), ('Going', 8), ('GO', 8), ('Went', 3), ('GOES', 1)]
# present [('presented', 48), ('present', 25), ('presents', 11), ('presenting', 9), ('Present', 1), ('Presented', 1), ('Presenting', 1)]
# ask [('asked', 231), ('ask', 185), ('asking', 98), ('asks', 18), ('Ask', 16), ('Asked', 12), ('Asking', 3), ('ASKED', 1), ('Asks', 1)]
# accept [('accept', 100), ('accepted', 84), ('accepting', 16), ('accepts', 6)]
# get [('get', 1400), ('got', 494), ('getting', 290), ('gets', 145), ('gotten', 47), ('Get', 41), ('Got', 19), ('Getting', 11), ('GET', 6), ('GOT', 4)]
# cease [('cease', 21), ('ceased', 6), ('ceases', 3)]
# want [('want', 952), ('wanted', 251), ('wants', 232), ('wanting', 43), ('Want', 15), ('WANT', 9), ('Wanted', 3), ('Wanting', 2), ('WANTED', 2), ('WANTS', 1)]
# believe [('believe', 519), ('believed', 94), ('believes', 75), ('believing', 18), ('Believe', 7), ('believeing', 1), ('BELIEVE', 1), ('Believing', 1)]
# have [('have', 3122), ('had', 1220), ('has', 1032), ('having', 282), ('Have', 18), ('Having', 15), ('Had', 8), ('’ve', 7), ('HAVE', 6), ('Has', 5)]
# adjust [('adjusted', 23), ('adjust', 13), ('adjusting', 5)]
# take [('take', 687), ('took', 338), ('taken', 238), ('taking', 227), ('takes', 105), ('Take', 35), ('Taking', 8), ('TAKE', 4), ('Taken', 3), ('Takes', 2)]
# see [('see', 956), ('seen', 281), ('saw', 198), ('seeing', 90), ('See', 38), ('sees', 31), ('Seeing', 8), ('Saw', 2), ('Seen', 2), ('SEE', 2)]
# think [('think', 1679), ('thought', 271), ('thinking', 124), ('thinks', 87), ('Think', 24), ('THINK', 5), ('Thinking', 4), ('Thought', 3), ('THINKS', 1), ('THINKING', 1)]
# win [('won', 148), ('win', 126), ('winning', 34), ('wins', 25), ('Winning', 4), ('WIN', 2), ('Win', 1)]
# find [('find', 426), ('found', 364), ('finding', 50), ('finds', 26), ('Find', 6), ('Found', 5), ('Finding', 4), ('FIND', 1)]
# default [('default', 5), ('defaulted', 1), ('defaulting', 1), ('defaults', 1)]
# die [('died', 177), ('die', 118), ('dying', 22), ('dies', 17), ('Died', 4), ('Die', 2), ('DIE', 1)]
# accord [('according', 245), ('According', 170), ('ACCORDING', 1), ('accord', 1)]
# happen [('happened', 192), ('happen', 177), ('happens', 105), ('happening', 73), ('HAPPEN', 2), ('HAPPENED', 2), ('Happens', 1), ('happend', 1), ('Happened', 1)]
# come [('come', 484), ('came', 298), ('comes', 220), ('coming', 186), ('Come', 17), ('Coming', 11), ('COME', 2), ('Came', 1), ('Comes', 1)]
# leave [('left', 259), ('leave', 180), ('leaving', 81), ('leaves', 27), ('Leave', 7), ('Leaving', 7), ('Left', 1)]
# occur [('occurred', 72), ('occur', 34), ('occurs', 17), ('occurring', 9)]
# buy [('buy', 243), ('bought', 108), ('buying', 92), ('buys', 14), ('Buy', 3), ('BUYING', 1), ('BUY', 1), ('Bought', 1)]
# gather [('gather', 14), ('gathered', 9), ('gathering', 5), ('Gathering', 1), ('gathers', 1)]
# increase [('increased', 182), ('increase', 138), ('increasing', 126), ('increases', 28), ('Increased', 7), ('Increasing', 6), ('Increase', 2), ('INCREASE', 2)]
# discover [('discovered', 62), ('discover', 8), ('discovering', 5), ('DISCOVERED', 1)]
# work [('work', 405), ('working', 281), ('worked', 163), ('works', 134), ('Working', 7), ('Works', 3), ('Work', 2), ('WORKING', 1), ('WORKED', 1)]
# speak [('speak', 81), ('speaking', 57), ('spoke', 44), ('speaks', 23), ('spoken', 19), ('Speaking', 12), ('Speak', 2), ('Spoken', 1), ('Spoke', 1)]
# eat [('eat', 53), ('eating', 26), ('ate', 10), ('eaten', 10), ('eats', 3)]
# live [('live', 254), ('living', 127), ('lived', 89), ('lives', 36), ('Live', 8), ('Living', 5), ('Lived', 2)]
# make [('make', 1028), ('made', 861), ('making', 341), ('makes', 312), ('Make', 18), ('Making', 14), ('Makes', 14), ('Made', 5), ('MAKE', 4), ('MADE', 1)]
# drink [('drink', 33), ('drinking', 13), ('drank', 9), ('drunk', 3), ('Drinking', 2), ('drinks', 2)]
# heat [('heated', 5), ('heating', 3), ('heat', 2), ('heats', 1)]
# sing [('sing', 20), ('sang', 13), ('singing', 13), ('sung', 5), ('sings', 2), ('Singing', 2), ('Sing', 1), ('Sings', 1)]
# arrive [('arrived', 69), ('arrive', 22), ('arriving', 13), ('arrives', 4), ('Arrived', 1), ('Arriving', 1), ('ARRIVED', 1)]
# drive [('driving', 43), ('drive', 43), ('drove', 36), ('driven', 24), ('drives', 5), ('Driving', 2), ('Drive', 2), ('DRIVING', 1), ('Drove', 1)]
# meet [('meet', 165), ('met', 132), ('meeting', 28), ('meets', 14), ('Meeting', 3), ('Meet', 2), ('Met', 2)]
# record [('recorded', 81), ('record', 17), ('recording', 10), ('Recorded', 2), ('RECORDED', 1), ('records', 1)]
# pass [('passed', 139), ('pass', 69), ('passing', 27), ('passes', 7), ('Passed', 2), ('Pass', 1)]
# file [('filed', 89), ('file', 12), ('filing', 6), ('File', 1), ('Filed', 1)]
# include [('including', 355), ('include', 164), ('included', 140), ('includes', 84), ('Including', 4), ('Included', 3), ('INCLUDE', 2), ('INCLUDING', 1)]
# beat [('beat', 44), ('beating', 24), ('beaten', 22), ('beats', 4), ('Beat', 3), ('Beats', 2), ('BEAT', 1)]
# permit [('permitted', 14), ('permit', 11), ('permitting', 7), ('permits', 5)]
# rain [('rain', 7), ('rains', 4), ('rained', 4), ('raining', 3)]
# trade [('traded', 32), ('trade', 19), ('trading', 18), ('Trading', 1), ('trades', 1)]
# cancel [('cancel', 16), ('canceled', 13), ('cancelled', 13), ('canceling', 3), ('cancelling', 1)]
# stop [('stop', 281), ('stopped', 108), ('stopping', 31), ('Stop', 27), ('stops', 14), ('STOP', 4), ('Stopping', 1)]
# continue [('continue', 213), ('continued', 114), ('continues', 79), ('continuing', 33), ('Continued', 3), ('Continuing', 2), ('CONTINUE', 1), ('Continues', 1), ('Continue', 1)]
# blame [('blame', 75), ('blamed', 32), ('blaming', 29), ('blames', 10), ('Blame', 5), ('Blaming', 3), ('Blamed', 1), ('Blames', 1)]
# let [('let', 295), ('Let', 123), ('letting', 28), ('lets', 27), ('LET', 3), ('Lets', 3), ('Letting', 2)]
# show [('show', 196), ('showed', 95), ('shows', 92), ('showing', 72), ('shown', 68), ('Show', 10), ('Shows', 4), ('SHOW', 2), ('Showing', 2), ('SHOWED', 1)]
# serve [('serve', 65), ('served', 51), ('serving', 27), ('serves', 19), ('Serve', 2)]
# retire [('retired', 32), ('retire', 12), ('retiring', 6), ('retires', 2), ('Retired', 1), ('RETIRE', 1), ('Retire', 1)]
# run [('run', 239), ('running', 138), ('ran', 80), ('runs', 37), ('Running', 3), ('Ran', 2), ('Run', 2), ('RUN', 1), ('RUNNING', 1)]
# carry [('carry', 97), ('carried', 84), ('carrying', 56), ('carries', 16), ('Carry', 7), ('Carried', 1)]
# fear [('fear', 37), ('feared', 19), ('fears', 10), ('fearing', 4)]
# rise [('rose', 158), ('rise', 57), ('rising', 42), ('risen', 23), ('rises', 10), ('Rising', 5)]
# taper [('taper', 4), ('tapers', 1), ('tapering', 1)]
# like [('like', 366), ('liked', 32), ('likes', 23), ('liking', 5), ('Like', 4), ('LIKE', 2), ('Likes', 1)]
# miss [('missing', 56), ('missed', 28), ('miss', 23), ('misses', 2), ('Missing', 1), ('Miss', 1), ('Missed', 1)]
# come. [('came.', 1), ('come.', 1)]
# saw. [('saw.', 1)]
# conquer [('conquered', 4), ('conquer', 3), ('conquering', 2)]
# know [('know', 1293), ('known', 190), ('knew', 129), ('knows', 123), ('knowing', 47), ('KNOW', 8), ('Know', 5), ('Known', 3), ('Knowing', 1), ('Knows', 1)]
# smoke [('smoking', 21), ('smoke', 15), ('smoked', 8), ('smokes', 3), ('Smoking', 2)]
# do [('do', 1419), ('did', 483), ('done', 369), ('doing', 320), ('does', 170), ('Do', 16), ('DO', 5), ('Doing', 4), ('Done', 3), ('Did', 3)]
# fly [('flying', 38), ('fly', 30), ('flew', 27), ('flown', 6), ('flies', 4), ('Flies', 1)]
# walk [('walking', 56), ('walk', 49), ('walked', 35), ('walks', 9), ('Walk', 2), ('Walking', 1)]
# back [('backed', 46), ('back', 46), ('backing', 20), ('backs', 6), ('Back', 2), ('Backed', 2), ('Backing', 1)]
# throw [('thrown', 32), ('throw', 28), ('threw', 26), ('throwing', 22), ('throws', 5), ('Throw', 3), ('Throws', 1), ('Thrown', 1), ('Threw', 1)]
# swim [('swimming', 11), ('swam', 2), ('swim', 2), ('swims', 2), ('SWIM', 1)]
# say [('said', 3242), ('say', 963), ('says', 690), ('saying', 381), ('Say', 12), ('Says', 11), ('Saying', 4), ('SAYING', 4), ('SAY', 4), ('SAID', 2)]
# support [('support', 241), ('supporting', 74), ('supported', 70), ('supports', 30), ('Support', 4), ('Supporting', 3), ('SUPPORT', 1)]
# break [('break', 65), ('broke', 56), ('broken', 41), ('breaking', 25), ('breaks', 9), ('Breaking', 2), ('Break', 1), ('Broken', 1), ('breaken', 1)]
# wait [('wait', 111), ('waiting', 74), ('waited', 20), ('Wait', 7), ('Waiting', 3), ('waits', 2)]
# stay [('stay', 117), ('stayed', 35), ('staying', 18), ('Stay', 6), ('stays', 5), ('STAY', 2), ('Stayed', 1)]
# propose [('proposed', 87), ('propose', 22), ('proposing', 15), ('proposes', 5), ('Propose', 1)]
# lower [('lower', 21), ('lowered', 21), ('lowering', 6), ('lowers', 3), ('Lowering', 1)]
# hire [('hire', 57), ('hired', 43), ('hiring', 20), ('Hiring', 2), ('hires', 2)]
# sail [('sailing', 4), ('sail', 3), ('sailed', 2), ('Sail', 1)]
# reach [('reached', 127), ('reach', 82), ('reaching', 35), ('reaches', 13), ('Reach', 1), ('Reached', 1)]
# sleep [('sleeping', 23), ('sleep', 20), ('slept', 7), ('Sleeping', 2), ('sleeps', 2), ('Sleep', 1)]
# laugh [('laugh', 36), ('laughing', 24), ('laughed', 14), ('LAUGHING', 1)]
# murder [('murdered', 40), ('murder', 9), ('murdering', 5), ('murders', 3), ('Murdered', 1), ('MURDER', 1)]
# annihilate [('annihilated', 2)]
# occure [('occured', 11), ('occuring', 1)]
# start [('started', 255), ('start', 207), ('starting', 76), ('starts', 37), ('Starting', 7), ('Start', 5), ('Started', 2), ('Starts', 2), ('STARTED', 1)]
# announce [('announced', 184), ('announce', 24), ('announcing', 10), ('announces', 5), ('Announces', 2)]
# advertise [('advertising', 6), ('advertised', 3), ('advertise', 3)]
# finish [('finished', 40), ('finish', 22), ('finishing', 8), ('Finish', 1)]
# cost [('cost', 86), ('costs', 31), ('costing', 14), ('costed', 1)]
# rest [('rest', 12), ('rests', 3), ('resting', 2), ('Rest', 1)]
# need [('need', 577), ('needed', 167), ('needs', 166), ('NEED', 9), ('needing', 6), ('Need', 5), ('Needs', 4), ('NEEDS', 1)]
# destroy [('destroyed', 87), ('destroy', 52), ('destroying', 20), ('destroys', 5), ('Destroy', 1), ('Destroys', 1)]
# lose [('lost', 233), ('lose', 119), ('losing', 64), ('loses', 14), ('Lost', 3), ('Losing', 2), ('LOSING', 2), ('Lose', 1)]
# open [('opened', 74), ('open', 64), ('opening', 47), ('opens', 9), ('Open', 2)]
# try [('trying', 364), ('try', 255), ('tried', 154), ('Try', 39), ('tries', 16), ('Trying', 5), ('TRY', 4), ('TRYING', 1)]
# look [('look', 334), ('looking', 201), ('looked', 81), ('looks', 73), ('Look', 48), ('Looks', 18), ('Looking', 16), ('LOOK', 1)]
# quit [('quit', 38), ('Quit', 2), ('quits', 1), ('quitting', 1), ('Quitting', 1)]
# leave. [('leave.', 1)]
# insist [('insisted', 29), ('insist', 24), ('insists', 14), ('insisting', 12)]
# arrest [('arrested', 158), ('arrest', 15), ('arresting', 4), ('Arrested', 2), ('Arrest', 1), ('arrests', 1)]
# reply [('replied', 20), ('reply', 13), ('replies', 4), ('Reply', 3), ('replying', 2)]
# uh [('uh', 1)]
# remember [('remember', 188), ('Remember', 29), ('remembers', 11), ('remembered', 9), ('remembering', 8), ('Remembering', 2), ('REMEMBER', 1)]
# travel [('travel', 31), ('traveled', 30), ('traveling', 9), ('travelled', 8), ('travelling', 8), ('travels', 4)]
# sit [('sitting', 64), ('sit', 50), ('sat', 19), ('sits', 13), ('Sit', 3), ('sittin\x92', 1), ('Sitting', 1)]
# repair [('repair', 13), ('repairing', 7), ('repaired', 3)]
# lobby [('lobbying', 7), ('lobbied', 4), ('lobby', 3), ('Lobbying', 1)]
# repeal [('repealed', 7), ('repeal', 6), ('Repealing', 3), ('Repeal', 2), ('repealing', 1)]
# agree [('agree', 272), ('agreed', 180), ('agreeing', 11), ('agrees', 9), ('Agreed', 8), ('Agree', 7), ('AGREED', 2)]
# dismantle [('dismantle', 12), ('dismantled', 10), ('dismantling', 4)]
# pay [('pay', 527), ('paid', 177), ('paying', 158), ('pays', 35), ('payed', 8), ('PAY', 8), ('Pay', 6), ('Paying', 4), ('PAYS', 1), ('PAID', 1)]
# dispose [('disposing', 3), ('disposed', 2), ('dispose', 1)]
# demand [('demand', 38), ('demanded', 36), ('demanding', 25), ('demands', 15), ('DEMAND', 1)]
# refuse [('refused', 92), ('refuse', 37), ('refusing', 26), ('refuses', 14), ('REFUSED', 6), ('Refused', 1)]
# testify [('testified', 13), ('testify', 7), ('testifying', 2), ('TESTIFY', 1), ('testifies', 1), ('Testifying', 1)]
# promise [('promised', 38), ('promise', 9), ('promises', 6), ('promising', 4), ('PROMISED', 2), ('Promise', 1), ('Promises', 1)]
# freeze [('frozen', 23), ('freeze', 18), ('freezes', 4), ('freezing', 3)]
# begin [('began', 213), ('begin', 109), ('begun', 45), ('beginning', 42), ('begins', 26), ('Beginning', 7)]
# snow [('snowed', 3), ('snowing', 2), ('snows', 1)]
# earn [('earned', 65), ('earn', 44), ('earning', 33), ('earns', 11), ('Earned', 1), ('earnt', 1), ('Earning', 1)]
# recommend [('recommend', 34), ('recommended', 23), ('recommends', 6), ('recommending', 1), ('Recommended', 1), ('Recommend', 1)]
# play [('played', 153), ('play', 129), ('playing', 85), ('plays', 22), ('Playing', 6), ('Play', 4), ('Played', 1), ('Plays', 1)]
# call [('called', 383), ('call', 218), ('calling', 113), ('calls', 49), ('Call', 10), ('Calling', 7), ('Calls', 2), ('CALL', 2), ('CALLED', 1), ('Called', 1)]
# send [('sent', 144), ('send', 106), ('sending', 45), ('sends', 14), ('Send', 4), ('Sending', 2), ('Sent', 1)]
# kill [('killed', 334), ('kill', 126), ('killing', 92), ('kills', 12), ('Kill', 9), ('KILL', 2), ('Killed', 1), ('Killing', 1), ('Kills', 1)]
# return [('returned', 93), ('return', 84), ('returning', 19), ('returns', 5), ('Returning', 2), ('Return', 2), ('RETURNS', 1)]
# renew [('renewed', 15), ('renew', 10), ('renewing', 6), ('Renewing', 1)]
# close [('closed', 102), ('close', 53), ('closing', 29), ('closes', 2), ('Closing', 1), ('Close', 1)]
# tell [('told', 374), ('tell', 262), ('telling', 98), ('tells', 51), ('Tell', 28), ('Telling', 5), ('TELL', 2), ('TELLING', 1)]
# elect [('elected', 96), ('elect', 11), ('electing', 5), ('Elected', 3)]
# interview [('interviewed', 24), ('interview', 14), ('interviewing', 3), ('Interviews', 1), ('Interviewing', 1)]
# identify [('identified', 55), ('identify', 31), ('identifies', 5), ('identifying', 2), ('IDENTIFIED', 1)]
# visit [('visited', 56), ('visit', 55), ('visiting', 24), ('Visit', 2), ('Visiting', 2), ('Visits', 1), ('visits', 1)]
# talk [('talking', 203), ('talk', 124), ('talked', 50), ('talks', 18), ('Talking', 7), ('Talk', 6), ('TALKING', 2)]
# clean [('clean', 28), ('cleaning', 15), ('cleaned', 7), ('cleans', 2), ('Cleaning', 1)]
# empty [('empty', 3), ('emptied', 3), ('empties', 1)]
# marry [('married', 94), ('marry', 47), ('marrying', 6), ('marries', 3), ('Married', 2), ('Marry', 2)]
# expect [('expected', 239), ('expect', 143), ('expects', 56), ('expecting', 25), ('Expect', 2)]
# spend [('spent', 172), ('spend', 117), ('spending', 47), ('spends', 16), ('Spent', 3)]
# launch [('launched', 101), ('launch', 37), ('launching', 19), ('launches', 2), ('LAUNCHED', 1)]
# read [('read', 266), ('reading', 70), ('Read', 37), ('reads', 15), ('READ', 10), ('Reading', 6)]
# cross [('crossed', 13), ('cross', 13), ('crossing', 9)]
# seat [('seated', 2), ('seats', 1)]
# keep [('keep', 393), ('kept', 76), ('keeping', 61), ('keeps', 46), ('Keep', 26), ('Keeping', 3), ('KEEP', 2)]
# give [('give', 444), ('given', 274), ('gave', 185), ('giving', 128), ('gives', 82), ('Given', 33), ('Give', 28), ('Giving', 6), ('GIVE', 3), ('GAVE', 2)]
# overcome [('overcome', 26), ('overcomes', 2), ('overcoming', 2), ('Overcoming', 1)]
# decorate [('decorate', 2), ('decorated', 1), ('Decorated', 1)]
# book [('booked', 9), ('book', 4), ('booking', 2)]
# hit [('hit', 166), ('hitting', 20), ('hits', 7), ('Hit', 3), ('Hits', 1)]
# catch [('caught', 74), ('catch', 27), ('catching', 5), ('Caught', 2), ('Catch', 1)]
# recover [('recovered', 32), ('recover', 20), ('recovering', 13), ('recovers', 3)]
# obtain [('obtain', 38), ('obtained', 27), ('obtaining', 13)]
# sell [('sell', 171), ('sold', 149), ('selling', 65), ('sells', 17), ('Selling', 4), ('SELL', 3), ('Sold', 3)]
# become [('become', 368), ('became', 223), ('becoming', 88), ('becomes', 55), ('BECOME', 2)]
# improve [('improve', 80), ('improved', 33), ('improving', 28), ('improves', 4), ('Improving', 1), ('Improve', 1)]
# recite [('recite', 2), ('recited', 1)]
# breathe [('breathe', 6), ('breathing', 6), ('BREATHING', 1)]
# surface [('surfaced', 3), ('surface', 2)]
# tempt [('tempted', 4), ('tempts', 1)]
# fall [('fell', 117), ('fall', 94), ('falling', 46), ('falls', 36), ('fallen', 33), ('Falling', 1), ('FALL', 1)]
# deliver [('delivered', 33), ('deliver', 29), ('delivering', 11), ('delivers', 5), ('Delivered', 1), ('deliverd', 1)]
# injure [('injured', 38), ('injuring', 9), ('injure', 2), ('Injure', 1)]
# shout [('shouted', 15), ('shouting', 13), ('shout', 4), ('shouts', 2)]
# cause [('caused', 151), ('cause', 105), ('causing', 52), ('causes', 33), ('Caused', 3), ('Cause', 2)]
# end [('end', 142), ('ended', 141), ('ending', 45), ('ends', 32), ('Ending', 3), ('END', 2), ('End', 1)]
# drown [('drowned', 7), ('drowning', 1)]
# sink [('sunk', 8), ('sank', 7), ('sink', 7), ('sinking', 3), ('sinks', 1)]
# shut [('shut', 56), ('SHUT', 5), ('Shut', 2), ('shutting', 2), ('shuts', 1)]
# oversleep [('overslept', 1), ('oversleep', 1)]
# predict [('predicted', 30), ('predict', 26), ('predicting', 15), ('predicts', 7)]
# act [('act', 72), ('acting', 54), ('acted', 22), ('acts', 13), ('Acts', 1)]
# own [('owned', 61), ('own', 52), ('owns', 52), ('owning', 8), ('OWN', 1)]
# solve [('solve', 38), ('solved', 17), ('solving', 7), ('solves', 2), ('Solving', 1), ('SOLVES', 1)]
# help [('help', 410), ('helped', 130), ('helping', 71), ('helps', 40), ('Help', 7), ('HELP', 1), ('HELPED', 1), ('Helped', 1), ('Helps', 1)]
# order [('ordered', 66), ('order', 14), ('ordering', 10), ('orders', 1), ('Ordered', 1)]
# slow [('slow', 17), ('slowing', 14), ('slowed', 12), ('Slowing', 1)]
# accelerate [('accelerate', 7), ('accelerating', 6), ('accelerated', 5), ('Accelerates', 1), ('accelerates', 1)]
# watch [('watch', 113), ('watching', 65), ('watched', 54), ('Watch', 7), ('Watching', 6), ('watches', 1)]
# wear [('wearing', 43), ('wear', 42), ('wore', 18), ('worn', 14), ('wears', 3), ('Wear', 3)]
# oppose [('opposed', 63), ('oppose', 43), ('opposing', 13), ('opposes', 6), ('Opposing', 2)]
# complain [('complain', 32), ('complained', 22), ('complaining', 22), ('complains', 7), ('Complain', 4)]
# advise [('advised', 24), ('advise', 11), ('advising', 9), ('advises', 4), ('Advised', 1)]
# love [('love', 149), ('loved', 43), ('loves', 24), ('loving', 9), ('LOVE', 9), ('Love', 8), ('Loves', 4), ('LOVED', 2), ('Loved', 1), ('Loving', 1)]
# cry [('cry', 21), ('crying', 15), ('cried', 6), ('Cry', 2), ('cries', 1), ('CRY', 1)]
# melt [('melt', 6), ('melting', 5), ('melted', 2)]
# last [('last', 32), ('lasted', 25), ('lasting', 8), ('lasts', 7), ('Lasting', 2)]
# double [('doubled', 12), ('double', 10), ('doubling', 5), ('doubles', 3), ('Doubled', 1)]
# use [('used', 518), ('use', 389), ('using', 258), ('uses', 49), ('Using', 16), ('Use', 3), ('USED', 3), ('Used', 2), ('USE', 2)]
# resign [('resigned', 26), ('resign', 15), ('resigning', 6)]
# blacken [('blackened', 1)]
# score [('scored', 9), ('score', 5), ('scoring', 2), ('scores', 1)]
# feel [('feel', 346), ('felt', 130), ('feeling', 50), ('feels', 41), ('Feel', 6), ('Felt', 2), ('FEEL', 2), ('Feeling', 1)]
# vote [('vote', 160), ('voted', 102), ('voting', 36), ('Voting', 4), ('Vote', 4), ('Voted', 3), ('VOTE', 3), ('votes', 2)]
# adopt [('adopted', 45), ('adopt', 36), ('adopting', 12), ('adopts', 2)]
# ensure [('ensure', 78), ('ensuring', 8), ('ensured', 3)]
# nominate [('nominated', 28), ('nominate', 11), ('nominating', 2), ('nominates', 2), ('Nominated', 2), ('Nominate', 1)]
# postpone [('postponed', 6), ('postpone', 4), ('postponing', 1)]
# chop [('chop', 2), ('chopping', 1), ('chopped', 1)]
# fail [('failed', 142), ('fail', 87), ('fails', 31), ('failing', 29), ('Fail', 5), ('Failing', 2), ('Failed', 1), ('Fails', 1)]
# remain [('remain', 128), ('remains', 83), ('remained', 65), ('remaining', 51), ('Remaining', 1), ('REMAINS', 1)]
# adhere [('adhere', 6), ('adhering', 1), ('adhered', 1)]
# sue [('sue', 21), ('sued', 18), ('suing', 6), ('Sue', 2), ('sueing', 2), ('Sues', 1)]
# fix [('fixed', 35), ('fix', 27), ('fixing', 12), ('FIX', 1), ('Fixing', 1), ('Fixed', 1)]
# bit [('bit', 5)]
# participate [('participate', 38), ('participated', 23), ('participating', 19), ('participates', 6), ('Participating', 2)]
# sign [('signed', 144), ('sign', 54), ('signing', 20), ('signs', 3), ('Sign', 2), ('SIGNED', 1), ('Signed', 1)]
# kiss [('kiss', 8), ('kissing', 4), ('kissed', 2), ('Kiss', 1)]
# treat [('treated', 85), ('treat', 41), ('treating', 15), ('treats', 2), ('Treating', 2), ('TREATED', 1)]
# induce [('induce', 4), ('induced', 4), ('inducing', 2), ('induces', 2)]
# introduce [('introduced', 55), ('introduce', 21), ('introducing', 10), ('introduces', 2), ('INTRODUCED', 1)]
# deacetylated [('deacetylated.', 1)]
# study [('study', 25), ('studied', 23), ('studying', 18), ('Study', 2), ('Studying', 2)]
# seize [('seized', 70), ('seize', 15), ('seizing', 3), ('seizes', 1)]
# move [('move', 143), ('moved', 120), ('moving', 75), ('moves', 8), ('Move', 6), ('Moving', 4), ('MOVE', 1), ('Moved', 1)]
# turn [('turned', 145), ('turn', 107), ('turning', 39), ('turns', 30), ('Turn', 5), ('Turns', 4), ('Turned', 1), ('Turning', 1)]
# concern [('concerned', 47), ('concerning', 43), ('concern', 7), ('concerns', 7), ('Concerning', 1)]
# estimate [('estimated', 96), ('estimate', 18), ('estimates', 17), ('Estimated', 3), ('estimating', 1)]
# damage [('damaged', 43), ('damaging', 7), ('damage', 7)]
# extract [('extract', 7), ('extracted', 5), ('Extracting', 1), ('Extracted', 1), ('extracting', 1)]
# hurt [('hurt', 77), ('hurting', 13), ('hurts', 12), ('Hurts', 1)]
# supply [('supply', 21), ('supplied', 20), ('supplying', 13), ('supplies', 7), ('SUPPLY', 1)]
# rage [('raging', 6), ('raged', 2), ('rage', 1)]
# promote [('promote', 62), ('promoting', 32), ('promoted', 19), ('promotes', 10), ('Promoting', 2)]
# effect [('effect', 12), ('effected', 6), ('effects', 4)]
# thwart [('thwart', 4), ('thwarted', 1), ('Thwarted', 1)]
# bomb [('bombed', 16), ('bomb', 12), ('bombing', 10)]
# appear [('appeared', 97), ('appear', 81), ('appears', 76), ('appearing', 17), ('Appearing', 2), ('Appears', 1)]
# strike [('struck', 46), ('strike', 27), ('strikes', 9), ('striking', 6), ('Strike', 3)]
# trigger [('triggered', 25), ('trigger', 8), ('triggering', 3), ('triggers', 2), ('Triggering', 1)]
# faint [('faint', 2), ('fainting', 1)]
# intend [('intended', 72), ('intend', 20), ('intends', 14), ('intending', 2), ('Intending', 1)]
# hide [('hide', 33), ('hiding', 17), ('hidden', 16), ('hid', 3), ('Hidden', 1)]
# hang [('hanged', 45), ('hang', 19), ('hanging', 17), ('hung', 7), ('hangs', 5), ('Hanging', 1), ('Hang', 1)]
# discuss [('discuss', 112), ('discussed', 55), ('discussing', 34), ('DISCUSS', 2), ('Discuss', 1), ('DISCUSSING', 1), ('Discussing', 1), ('discusses', 1)]
# attend [('attended', 52), ('attend', 31), ('attending', 23), ('Attending', 1)]
# bike [('Biking', 1)]
# save [('save', 98), ('saved', 41), ('saving', 18), ('Save', 5), ('saves', 3), ('SAVED', 1), ('Saved', 1)]
# weigh [('weighed', 12), ('weigh', 11), ('weighs', 6), ('weighing', 1)]
# surprise [('surprised', 30), ('surprise', 9), ('surprises', 3), ('surprising', 1), ('SURPRISED', 1)]
# raise [('raised', 114), ('raise', 88), ('raising', 55), ('raises', 26), ('Raising', 7), ('Raise', 3), ('Raised', 2)]
# examine [('examined', 15), ('examine', 14), ('examining', 5), ('examines', 2)]
# attenuate [('attenuated', 1)]
# thank [('Thank', 51), ('thank', 47), ('thanked', 7), ('THANK', 2), ('Thanking', 1)]
# organise [('organised', 6), ('organising', 6), ('organise', 2)]
# fire [('fired', 70), ('fire', 14), ('firing', 11), ('Fire', 1), ('fires', 1)]
# require [('required', 83), ('require', 67), ('requires', 46), ('requiring', 24), ('Requires', 1)]
# tune [('tuned', 6), ('tune', 4), ('tuning', 3)]
# hear [('heard', 175), ('hear', 126), ('hearing', 39), ('hears', 4), ('HEARD', 2), ('Heard', 2), ('Hear', 1)]
# mean [('mean', 328), ('means', 194), ('meant', 79), ('meaning', 23), ('Meaning', 3), ('Means', 3), ('MEAN', 2), ('Meant', 1)]
# google [('google', 6), ('googled', 5), ('Googled', 1), ('Google', 1), ('googling', 1)]
# understand [('understand', 284), ('understood', 32), ('understanding', 18), ('understands', 11), ('Understand', 1)]
# divorce [('divorced', 16), ('divorcing', 3), ('divorce', 2)]
# shine [('shines', 5), ('shining', 4), ('shine', 4), ('shone', 4)]
# click [('click', 9), ('clicked', 4), ('clicking', 1)]
# write [('wrote', 160), ('written', 111), ('write', 58), ('writing', 42), ('writes', 29), ('WROTE', 2), ('Writing', 2), ('Write', 1), ('Writes', 1)]
# correlate [('correlated', 1), ('correlate', 1)]
# activate [('activated', 12), ('activate', 2), ('activating', 2)]
# confirm [('confirmed', 64), ('confirm', 19), ('confirming', 9), ('confirms', 9)]
# register [('registered', 24), ('register', 14), ('registering', 4), ('Registered', 1)]
# appeal [('appeal', 23), ('appealed', 21), ('appealing', 2), ('appeals', 2), ('Appeal', 1)]
# condemn [('condemned', 19), ('condemn', 15), ('condemning', 8), ('condemns', 4)]
# restore [('restore', 29), ('restored', 14), ('restoring', 12), ('Restore', 3), ('Restoring', 2), ('Restored', 1)]
# view [('view', 30), ('viewed', 26), ('views', 10), ('viewing', 8)]
# fuck [('fucking', 74), ('fuck', 22), ('Fuck', 16), ('fucked', 12), ('Fucking', 7), ('FUCK', 5)]
# wish [('wish', 106), ('wished', 19), ('wishes', 11), ('wishing', 11), ('Wish', 4), ('Wishing', 1)]
# commit [('committed', 60), ('commit', 47), ('committing', 15), ('commits', 3)]
# convince [('convinced', 29), ('convince', 22), ('convincing', 8)]
# celebrate [('celebrate', 20), ('celebrated', 9), ('celebrating', 5), ('Celebrating', 1), ('celebrates', 1)]
# bind [('bound', 20), ('binding', 6), ('binds', 4), ('bind', 2), ('Bound', 1)]
# determine [('determine', 42), ('determined', 38), ('determining', 7), ('determines', 5), ('Determining', 2), ('Determined', 1)]
# prepare [('prepared', 46), ('preparing', 31), ('prepare', 26), ('prepares', 7)]
# divide [('divided', 24), ('divide', 9), ('divides', 5), ('dividing', 3), ('DIVIDED', 1)]
# equal [('equals', 8), ('equaling', 7), ('equal', 3), ('equaled', 1)]
# ride [('riding', 19), ('ride', 15), ('ridden', 7), ('rode', 5)]
# fit [('fit', 33), ('fits', 9), ('fitting', 3), ('fitted', 1)]
# dance [('dance', 8), ('danced', 4), ('dancing', 4), ('dances', 1), ('Dancing', 1), ('Dance', 1)]
# enter [('entered', 39), ('enter', 35), ('entering', 26), ('Entering', 3), ('enters', 3), ('Enter', 2)]
# decrease [('decreased', 18), ('decrease', 18), ('decreasing', 15), ('decreases', 2), ('Decreasing', 1)]
# lend [('lend', 11), ('lent', 3), ('lending', 2), ('Lend', 1), ('lends', 1)]
# lead [('led', 130), ('lead', 112), ('leading', 98), ('leads', 29), ('Leading', 5), ('LEAD', 1)]
# owe [('owed', 12), ('owes', 12), ('owe', 12), ('OWE', 1)]
# encourage [('encourage', 30), ('encouraged', 29), ('encouraging', 19), ('encourages', 11), ('Encouraged', 1)]
# consider [('considered', 166), ('consider', 112), ('considering', 66), ('considers', 17), ('Consider', 12), ('Considering', 12), ('Considered', 4)]
# load [('loaded', 8), ('load', 4), ('loads', 1)]
# publish [('published', 67), ('publishing', 8), ('publish', 6), ('Published', 6), ('publishes', 3)]
# persecute [('persecuting', 5), ('persecuted', 3), ('persecute', 1)]
# perform [('performed', 73), ('perform', 36), ('performing', 36), ('performs', 5), ('Performing', 1), ('Performed', 1)]
# compare [('compared', 125), ('compare', 28), ('comparing', 19), ('compares', 9), ('Compared', 8), ('Comparing', 3), ('Compare', 3), ('Compares', 1), ('COMPARE', 1)]
# struggle [('struggling', 26), ('struggled', 12), ('struggle', 8), ('struggles', 4), ('Struggling', 1)]
# afford [('afford', 107), ('afforded', 8), ('affords', 2), ('affording', 1)]
# suggest [('suggest', 89), ('suggested', 71), ('suggesting', 33), ('suggests', 28), ('Suggesting', 1)]
# expel [('expelled', 4), ('expel', 3), ('expelling', 2), ('Expelling', 1)]
# bark [('barked', 2), ('bark', 2), ('barking', 2)]
# enrich [('enriched', 5), ('enriching', 4), ('enrich', 3)]
# respect [('respect', 49), ('respected', 11), ('respecting', 4), ('Respect', 1)]
# locate [('located', 78), ('locate', 5)]
# learn [('learn', 96), ('learned', 68), ('learning', 32), ('learnt', 6), ('Learn', 4), ('LEARN', 1), ('Learning', 1)]
# finished [('finished', 1)]
# veto [('veto', 18), ('vetoed', 6), ('vetoes', 2), ('vetoing', 1)]
# cut [('cut', 196), ('cutting', 62), ('cuts', 5), ('Cutting', 3), ('Cut', 2), ('CUT', 1)]
# form [('formed', 49), ('form', 31), ('forming', 13), ('forms', 3)]
# hold [('held', 226), ('hold', 136), ('holding', 80), ('holds', 37), ('Hold', 9), ('Holding', 1), ('HELD', 1), ('HOLD', 1)]
# create [('created', 158), ('create', 123), ('creating', 61), ('creates', 26), ('Created', 5), ('Creating', 3), ('Create', 2), ('CREATED', 1), ('CREATING', 1)]
# endow [('endowed', 2), ('endow', 1)]
# phosphorylate [('phosphorylates', 1), ('phosphorylated', 1)]
# establish [('established', 90), ('establish', 60), ('establishing', 24), ('establishes', 8), ('Establishing', 2), ('Establish', 1)]
# invent [('invented', 9), ('invent', 4), ('Invented', 2), ('inventing', 1)]
# formulate [('formulated', 4), ('formulate', 4)]
# choose [('choose', 99), ('chose', 60), ('chosen', 32), ('choosing', 17), ('chooses', 6), ('Choose', 3), ('CHOOSE', 1)]
# conduct [('conduct', 28), ('conducted', 25), ('conducting', 21), ('conducts', 3)]
# pick [('pick', 62), ('picked', 37), ('picking', 17), ('Pick', 3), ('picks', 3)]
# assess [('assess', 15), ('assessed', 5), ('assessing', 5), ('assesses', 1), ('Assessing', 1)]
# preserve [('preserve', 13), ('preserving', 7), ('preserved', 1)]
# collapse [('collapsed', 26), ('collapses', 5), ('collapsing', 4), ('collapse', 4)]
# arouse [('arousing', 3), ('aroused', 2)]
# alleviate [('alleviate', 7), ('alleviating', 1)]
# leak [('leaked', 10), ('leaking', 5), ('leak', 3), ('leaks', 3)]
# accumulate [('accumulated', 8), ('accumulate', 4)]
# warn [('warned', 66), ('warning', 15), ('warn', 10), ('warns', 9), ('WARNS', 2)]
# spread [('spread', 49), ('spreading', 23), ('spreads', 3)]
# reduce [('reduce', 90), ('reduced', 52), ('reducing', 15), ('reduces', 12), ('Reducing', 4), ('Reduce', 1)]
# undertake [('undertook', 9), ('undertake', 4), ('undertaken', 4), ('undertaking', 2)]
# pull [('pulled', 45), ('pull', 44), ('pulling', 27), ('pulls', 6), ('Pulled', 1), ('Pull', 1)]
# measure [('measured', 13), ('measure', 11), ('measuring', 5), ('measures', 4)]
# judge [('judge', 27), ('judged', 14), ('judging', 9), ('Judging', 1)]
# design [('designed', 58), ('design', 10), ('designing', 7), ('DESIGNED', 4), ('designs', 2)]
# block [('blocked', 34), ('block', 22), ('blocking', 10), ('blocks', 3), ('Block', 2)]
# obstruct [('obstructing', 3), ('obstruct', 1), ('obstructed', 1)]
# assume [('assume', 91), ('assuming', 29), ('assumed', 23), ('assumes', 11), ('Assuming', 5), ('Assume', 4), ('ASSUME', 1), ('ASSUMING', 1)]
# rush [('rush', 12), ('rushed', 11), ('rushing', 6), ('rushes', 3)]
# bring [('brought', 159), ('bring', 151), ('bringing', 46), ('brings', 32), ('Bringing', 4), ('Bring', 4), ('BRING', 1)]
# maintain [('maintain', 66), ('maintained', 25), ('maintaining', 23), ('maintains', 9), ('Maintaining', 2)]
# rely [('rely', 32), ('relied', 13), ('relying', 11), ('relies', 7), ('Relying', 1)]
# deal [('deal', 85), ('dealing', 41), ('dealt', 21), ('deals', 4), ('Deal', 4)]
# construct [('constructed', 12), ('construct', 7), ('constructing', 6), ('constructs', 1)]
# result [('resulted', 48), ('resulting', 38), ('result', 33), ('results', 10)]
# drag [('dragged', 8), ('dragging', 7), ('drag', 5), ('drags', 1), ('Dragging', 1)]
# contact [('contact', 10), ('contacted', 6), ('contacting', 3)]
# forget [('forget', 41), ('forgotten', 19), ('forgot', 13), ('Forget', 6), ('forgetting', 3), ('forgets', 2), ('Forgetting', 1), ('Forgot', 1)]
# strip [('stripped', 7), ('strip', 4), ('stripping', 2), ('Stripped', 1)]
# compose [('composed', 14), ('compose', 2)]
# expose [('exposed', 26), ('exposing', 9), ('expose', 8), ('exposes', 2)]
# delude [('deluded', 4), ('delude', 2), ('deluding', 1)]
# lay [('laid', 39), ('lay', 26), ('laying', 12), ('layed', 1), ('LAID', 1), ('Lay', 1)]
# avoid [('avoid', 85), ('avoided', 16), ('avoiding', 12), ('avoids', 1), ('Avoid', 1)]
# embarrass [('embarrassed', 9), ('embarrassing', 5), ('embarrass', 4), ('Embarrass', 1)]
# sacrifice [('sacrifice', 12), ('sacrificed', 8), ('Sacrificing', 1), ('sacrifices', 1)]
# engage [('engaged', 42), ('engage', 26), ('engaging', 12), ('engages', 3)]
# flash [('flashed', 4), ('flashing', 3), ('flash', 1)]
# manufacture [('manufacture', 15), ('manufactured', 15), ('manufacturing', 13), ('manufactures', 4)]
# produce [('produced', 103), ('produce', 98), ('producing', 56), ('produces', 17), ('PRODUCE', 1), ('Produced', 1), ('Producing', 1), ('Produce', 1)]
# pop [('pops', 4), ('popped', 3), ('pop', 3), ('popping', 1)]
# involve [('involved', 124), ('involving', 39), ('involve', 24), ('involves', 20), ('Involving', 1)]
# fulfill [('fulfill', 8)]
# stick [('stick', 34), ('stuck', 29), ('sticking', 13), ('sticks', 5), ('Stick', 5)]
# seem [('seems', 295), ('seem', 226), ('seemed', 53), ('Seems', 27), ('seeming', 1), ('SEEMS', 1), ('Seem', 1)]
# lie [('lying', 84), ('lie', 53), ('lies', 30), ('lied', 25), ('Lied', 2), ('LIE', 2), ('Lie', 1), ('Lying', 1)]
# deploy [('deployed', 25), ('deploy', 11), ('deploying', 6), ('deploys', 1)]
# allocate [('allocated', 10), ('allocate', 6), ('allocating', 1)]
# compensate [('compensate', 8), ('compensated', 2), ('compensates', 1)]
# check [('check', 56), ('checked', 23), ('Check', 10), ('checking', 8), ('checks', 5), ('CHECK', 5)]
# frightening. [('frightening.', 1)]
# climb [('climbed', 19), ('climb', 8), ('climbing', 5), ('climbs', 4)]
# head [('headed', 45), ('head', 20), ('heads', 13), ('heading', 11), ('Head', 1)]
# control [('control', 64), ('controlled', 47), ('controlling', 23), ('controls', 11), ('Controlled', 1), ('Controlling', 1)]
# limit [('limit', 31), ('limited', 21), ('limiting', 12), ('limits', 12), ('Limiting', 2), ('LIMIT', 1)]
# band [('banded', 2), ('banding', 1), ('band', 1)]
# yell [('yelled', 5), ('yell', 4), ('yells', 3), ('yelling', 2)]
# guess [('guess', 140), ('Guess', 15), ('guessed', 8), ('guessing', 7), ('GUESS', 1), ('Guessing', 1), ('guesses', 1)]
# overload [('overloaded', 3), ('overload', 1), ('overloading', 1)]
# connect [('connected', 28), ('connect', 8), ('connecting', 4), ('connects', 2)]
# dial [('dialed', 2), ('dial', 2), ('dialing', 2)]
# partake [('partaking', 2), ('partake', 1)]
# underscore [('underscored', 5), ('underscores', 1)]
# grow [('growing', 96), ('grow', 93), ('grew', 43), ('grown', 42), ('grows', 18), ('Grow', 5), ('Growing', 3), ('Grows', 1)]
# widen [('widening', 4), ('widen', 3), ('widens', 1)]
# admit [('admit', 78), ('admitted', 61), ('admitting', 21), ('admits', 14), ('Admits', 1), ('Admitting', 1)]
# note [('noted', 71), ('note', 29), ('notes', 19), ('Note', 10), ('noting', 10), ('Noted', 1), ('Noting', 1)]
# hail [('hailed', 4), ('hailing', 2), ('hail', 1)]
# allege [('alleged', 67), ('alleging', 8), ('alleges', 6), ('allege', 3)]
# donate [('donated', 18), ('donate', 15), ('donating', 9), ('Donating', 1), ('Donate', 1), ('donates', 1)]
# deviate [('deviate', 2)]
# seek [('seeking', 81), ('seek', 72), ('sought', 42), ('seeks', 34)]
# exhibit [('exhibited', 8), ('exhibits', 2), ('exhibiting', 1), ('exhibit', 1)]
# besiege [('besieged', 2), ('besiege', 1), ('besieging', 1)]
# subject [('subjected', 17), ('subjecting', 4), ('subjects', 1), ('subject', 1)]
# urge [('urged', 46), ('urges', 14), ('urging', 13), ('urge', 10), ('Urges', 2), ('Urging', 1), ('URGED', 1)]
# bestow [('bestowing', 3), ('bestow', 2), ('bestowed', 1)]
# satisfy [('satisfy', 10), ('satisfied', 5), ('Satisfying', 1), ('satisfies', 1), ('satisfying', 1)]
# clarify [('clarify', 21), ('clarifying', 4), ('clarified', 3), ('Clarifying', 1), ('Clarify', 1)]
# offer [('offered', 152), ('offer', 93), ('offering', 36), ('offers', 24), ('OFFERED', 4), ('Offered', 3), ('OFFER', 1)]
# express [('expressed', 75), ('express', 27), ('expressing', 8), ('expresses', 5)]
# suffer [('suffered', 54), ('suffering', 41), ('suffer', 35), ('suffers', 10), ('Suffer', 1)]
# clear [('clear', 25), ('cleared', 12), ('clearing', 3), ('clears', 2), ('Clear', 1), ('CLEARS', 1)]
# put [('put', 432), ('putting', 84), ('puts', 29), ('Put', 6), ('Putting', 5), ('PUT', 3), ('Puts', 1)]
# deceive [('deceived', 4), ('deceive', 2)]
# advocate [('advocate', 15), ('advocating', 12), ('advocated', 9), ('advocates', 3)]
# unite [('unite', 7), ('united', 3), ('uniting', 3), ('Uniting', 1), ('unites', 1)]
# erupt [('erupted', 10), ('erupt', 2), ('erupting', 1), ('erupts', 1)]
# realize [('realize', 107), ('realized', 30), ('realizing', 7), ('realizes', 5), ('Realizing', 1)]
# dream [('dream', 6), ('dreamed', 4), ('dreaming', 3), ('dreamt', 1)]
# exist [('exist', 87), ('existing', 51), ('exists', 51), ('existed', 20), ('Existing', 1)]
# hand [('handed', 25), ('handing', 12), ('hand', 12), ('hands', 1)]
# grab [('grab', 11), ('grabbed', 6), ('grabbing', 3), ('GRAB', 1)]
# wreak [('wreaked', 1)]
# draw [('draw', 36), ('drew', 26), ('drawn', 25), ('drawing', 9), ('draws', 6)]
# undergo [('undergone', 5), ('undergo', 4), ('underwent', 4), ('undergoes', 3), ('undergoing', 3)]
# experience [('experienced', 46), ('experience', 15), ('experiencing', 10), ('Experiencing', 1), ('experiences', 1)]
# place [('placed', 39), ('place', 12), ('placing', 10), ('places', 5), ('Placing', 1)]
# follow [('following', 180), ('followed', 89), ('follow', 76), ('Following', 41), ('follows', 21), ('Follow', 3), ('Followed', 2), ('FOLLOW', 1)]
# wipe [('wiped', 16), ('wipe', 6), ('wiping', 6), ('Wipe', 2), ('wipes', 2)]
# bury [('buried', 43), ('bury', 7), ('burying', 2), ('Buries', 1)]
# brace [('bracing', 4), ('braced', 1), ('brace', 1)]
# declare [('declared', 61), ('declaring', 13), ('declare', 12), ('declares', 4), ('Declare', 2), ('Declaring', 1)]
# shake [('shaking', 14), ('shake', 12), ('shook', 6), ('shaken', 5), ('Shaken', 2), ('shakes', 2)]
# revitalize [('revitalize', 3)]
# enable [('enable', 18), ('enabling', 13), ('enabled', 11), ('enables', 4), ('Enable', 1)]
# reappear [('reappeared', 3), ('reappears', 1)]
# pray [('pray', 16), ('praying', 9), ('Pray', 1), ('prayed', 1)]
# trap [('trapped', 19), ('traps', 1)]
# settle [('settled', 32), ('settle', 28), ('settling', 8), ('settles', 1), ('Settle', 1)]
# stretch [('stretching', 6), ('stretched', 4), ('stretch', 4), ('stretches', 3)]
# set [('set', 233), ('setting', 30), ('sets', 11), ('Set', 2), ('Setting', 2)]
# contain [('contained', 29), ('containing', 25), ('contain', 24), ('contains', 13)]
# displace [('displaced', 7), ('displaces', 3), ('displacing', 2), ('displace', 1)]
# shelter [('shelter', 3), ('sheltered', 1), ('sheltering', 1)]
# expropriate [('expropriate', 1), ('expropriated', 1)]
# override [('override', 5), ('overriding', 2), ('overrides', 2)]
# test [('tested', 20), ('test', 18), ('testing', 8), ('tests', 5), ('Testing', 1)]
# rule [('ruled', 48), ('rule', 30), ('ruling', 29), ('rules', 3), ('Rule', 1)]
# stand [('stand', 91), ('standing', 59), ('stood', 39), ('stands', 34), ('Stand', 7), ('Standing', 1), ('STANDING', 1)]
# count [('count', 33), ('counting', 13), ('counts', 10), ('counted', 9), ('Count', 2)]
# flaunt [('flaunt', 1), ('flaunts', 1)]
# trace [('traced', 6), ('trace', 4), ('traces', 1), ('tracing', 1)]
# distinguish [('distinguish', 11), ('distinguished', 3), ('distinguishing', 2), ('distinguishes', 1)]
# stabilize [('stabilize', 12), ('stabilized', 5), ('stabilizing', 3)]
# value [('valued', 27), ('value', 16), ('values', 3), ('Value', 1), ('valuing', 1), ('Valued', 1)]
# destabilize [('destabilizing', 5), ('destabilized', 1), ('destabilizes', 1)]
# care [('care', 172), ('cares', 31), ('cared', 25), ('caring', 12), ('Care', 5), ('CARE', 2), ('CARES', 1)]
# waste [('waste', 16), ('wasted', 15), ('wasting', 14), ('wastes', 2), ('Wasted', 1)]
# despise [('despise', 7), ('despised', 2)]
# stipulate [('stipulates', 7), ('stipulated', 5), ('stipulating', 1)]
# exceed [('exceed', 16), ('exceeds', 9), ('exceeded', 9), ('exceeding', 8)]
# affect [('affected', 73), ('affect', 61), ('affecting', 14), ('affects', 13), ('AFFECTING', 1), ('Affected', 1)]
# admonish [('admonishing', 1), ('admonished', 1)]
# force [('forced', 137), ('force', 71), ('forcing', 37), ('forces', 7), ('FORCE', 3), ('Forcing', 3), ('Forced', 2), ('Forces', 1), ('FORCES', 1)]
# rebuke [('rebuking', 1)]
# prevent [('prevent', 117), ('preventing', 29), ('prevented', 22), ('prevents', 10), ('Preventing', 1)]
# restrict [('restrict', 16), ('restricted', 6), ('restricting', 6), ('restricts', 3)]
# list [('listed', 43), ('list', 10), ('lists', 9), ('listing', 7)]
# appropriate [('appropriated', 5)]
# exhaust [('exhausted', 11)]
# embezzle [('embezzled', 5), ('embezzle', 1)]
# transfer [('transferred', 32), ('transfer', 18), ('transferring', 11), ('Transferred', 2), ('transfers', 2), ('Transferring', 1), ('transfered', 1)]
# negate [('negate', 3), ('negated', 1)]
# push [('push', 47), ('pushed', 36), ('pushing', 32), ('pushes', 10), ('PUSH', 1)]
# regulate [('regulate', 16), ('regulated', 14), ('regulating', 3), ('regulates', 2), ('Regulate', 1)]
# depart [('departed', 12), ('depart', 9), ('departs', 2), ('departing', 1)]
# emphasize [('emphasized', 15), ('emphasize', 7), ('emphasizes', 4), ('emphasizing', 2), ('Emphasized', 1)]
# apply [('apply', 50), ('applied', 31), ('applies', 17), ('applying', 9), ('Applied', 1), ('Apply', 1)]
# evaluate [('evaluate', 8), ('evaluating', 7), ('evaluated', 3)]
# face [('face', 72), ('faced', 49), ('facing', 45), ('faces', 22), ('Facing', 4), ('Faced', 2), ('Face', 2), ('FACED', 1)]
# achieve [('achieved', 40), ('achieve', 36), ('achieving', 11)]
# doom [('doomed', 8), ('dooms', 1), ('dooming', 1)]
# issue [('issued', 116), ('issue', 24), ('issuing', 7), ('issues', 1)]
# censure [('censured', 2)]
# regard [('regarding', 86), ('regarded', 25), ('Regarding', 13), ('regard', 9), ('REGARDING', 1), ('regards', 1)]
# minimize [('minimize', 8), ('minimizing', 1)]
# pursue [('pursue', 29), ('pursuing', 15), ('pursued', 13), ('pursues', 1), ('PURSUED', 1), ('PURSUE', 1)]
# embody [('embodies', 3), ('embodied', 2), ('embody', 2)]
# relate [('related', 48), ('relating', 17), ('relate', 7), ('relates', 4), ('Related', 1)]
# entangle [('entangled', 3)]
# confine [('confined', 6), ('confine', 2)]
# intervene [('intervene', 24), ('intervened', 16), ('intervening', 6), ('intervenes', 1)]
# supervise [('supervised', 5), ('supervise', 3), ('supervising', 2)]
# perfect [('perfect', 4), ('perfected', 3)]
# neglect [('neglected', 5), ('neglecting', 2), ('neglect', 1)]
# emit [('emitted', 2), ('emit', 1)]
# gallop [('galloping', 2)]
# bother [('bother', 42), ('bothered', 16), ('bothering', 7), ('bothers', 7)]
# defeat [('defeated', 19), ('defeat', 15), ('defeating', 4), ('defeats', 3)]
# claim [('claim', 123), ('claimed', 115), ('claiming', 50), ('claims', 45), ('CLAIM', 1), ('CLAIMS', 1), ('Claim', 1), ('Claimed', 1)]
# build [('build', 144), ('built', 111), ('building', 69), ('Building', 2), ('builds', 2), ('Built', 1)]
# entertain [('entertained', 5), ('entertain', 4), ('entertaining', 1)]
# inspire [('inspired', 26), ('inspire', 8), ('inspires', 4), ('inspiring', 3), ('Inspired', 1)]
# advance [('advanced', 27), ('advance', 13), ('advancing', 7), ('Advancing', 2), ('advances', 1)]
# repeat [('repeated', 21), ('repeat', 17), ('repeating', 9), ('repeats', 2), ('Repeating', 1)]
# belong [('belong', 26), ('belongs', 15), ('belonging', 11), ('belonged', 8), ('Belong', 2)]
# manage [('managed', 52), ('managing', 32), ('manage', 28), ('manages', 5), ('Managing', 3)]
# separate [('separated', 13), ('separate', 7), ('separating', 4), ('separates', 4)]
# forecast [('forecast', 15), ('forecasting', 2), ('forecasts', 2), ('Forecasting', 1)]
# differentiate [('differentiate', 6), ('differentiated', 2)]
# complicate [('complicated', 12), ('complicate', 7), ('complicates', 1)]
# converge [('converged', 3), ('converge', 2)]
# intersect [('intersect', 1), ('intersects', 1)]
# withstand [('withstand', 8), ('withstood', 3)]
# reassure [('reassured', 3), ('reassure', 2)]
# provide [('provide', 223), ('provided', 106), ('providing', 83), ('provides', 53), ('Provide', 6), ('Providing', 2)]
# dare [('dare', 27), ('dares', 4), ('dared', 2), ('daring', 1), ('DARE', 1)]
# access [('access', 8), ('accessing', 3), ('accesses', 1), ('accessed', 1)]
# enact [('enacted', 9), ('enact', 4), ('enacting', 1)]
# comply [('comply', 17), ('complied', 1), ('Complying', 1)]
# reinforce [('reinforce', 7), ('reinforced', 3), ('reinforcing', 3), ('reinforces', 1)]
# remove [('removed', 52), ('remove', 45), ('removing', 21), ('Removing', 3), ('removes', 2)]
# shirk [('shirk', 2), ('shirking', 1)]
# stun [('stunned', 5), ('stuns', 1), ('stunning', 1)]
# crumble [('crumble', 3), ('crumbled', 2), ('crumbles', 1), ('crumbling', 1)]
# inspect [('inspect', 10), ('inspected', 9), ('inspecting', 2)]
# complete [('completed', 71), ('complete', 22), ('completing', 11), ('completes', 2), ('Completed', 1)]
# allow [('allowed', 196), ('allow', 156), ('allowing', 55), ('allows', 37), ('Allowing', 7), ('Allow', 3), ('ALLOWED', 2)]
# revive [('revived', 9), ('revive', 9), ('reviving', 1)]
# assign [('assigned', 16), ('assign', 4), ('assigning', 3)]
# point [('pointed', 55), ('point', 44), ('pointing', 38), ('points', 20), ('Point', 3)]
# shudder [('shudder', 2), ('Shuddering', 1)]
# rattle [('rattled', 5), ('rattle', 2), ('RATTLED', 1)]
# convalesce [('convalescing', 1)]
# recruit [('recruited', 14), ('recruiting', 1), ('recruit', 1)]
# cope [('cope', 23), ('coping', 6), ('coped', 1)]
# cooperate [('cooperate', 36), ('cooperating', 10)]
# monitor [('monitor', 20), ('monitoring', 11), ('monitors', 4), ('monitored', 3)]
# operate [('operating', 62), ('operate', 36), ('operates', 12), ('operated', 11)]
# gain [('gained', 65), ('gain', 56), ('gaining', 17), ('gains', 1)]
# develop [('develop', 80), ('developing', 79), ('developed', 54), ('develops', 8), ('Developing', 4)]
# contract [('contracted', 14), ('contracting', 3), ('contract', 1)]
# disband [('disbanded', 5), ('disband', 1)]
# change [('change', 183), ('changed', 115), ('changing', 53), ('changes', 25), ('Change', 4), ('CHANGE', 3), ('Changing', 2), ('Changed', 1)]
# root [('rooted', 7), ('rooting', 3), ('root', 2)]
# corner [('cornered', 3)]
# profit [('profit', 17), ('profiting', 4), ('profits', 2), ('profited', 1)]
# trample [('tramples', 3), ('trample', 2), ('trampled', 2)]
# maximize [('maximize', 4), ('maximizing', 3)]
# receive [('received', 190), ('receive', 90), ('receiving', 42), ('receives', 13), ('Receiving', 1)]
# cure [('cured', 4), ('cure', 3)]
# annex [('annex', 2), ('annexing', 1)]
# team [('teamed', 2), ('teaming', 2), ('team', 1), ('teams', 1)]
# demonstrate [('demonstrate', 20), ('demonstrated', 14), ('demonstrates', 7), ('demonstrating', 6)]
# reap [('reap', 8), ('REAP', 1), ('reaped', 1)]
# attract [('attract', 33), ('attracted', 26), ('attracting', 9), ('attracts', 5), ('ATTRACTING', 1)]
# convey [('convey', 8), ('conveys', 3), ('conveyed', 2), ('conveying', 1), ('conveyes', 1)]
# bargain [('bargaining', 3), ('bargained', 1), ('bargain', 1)]
# disillusion [('disillusioned', 3)]
# hope [('hope', 196), ('hoping', 50), ('hopes', 34), ('hoped', 31), ('Hope', 12), ('Hoping', 7), ('HOPE', 1), ('HOPED', 1)]
# bump [('bump', 3)]
# represent [('represent', 41), ('represents', 35), ('representing', 27), ('represented', 21)]
# prove [('prove', 88), ('proven', 49), ('proved', 34), ('proves', 23), ('proving', 21), ('PROVE', 7), ('Prove', 3), ('PROVING', 2), ('Proving', 1), ('Proves', 1)]
# lack [('lack', 21), ('lacking', 14), ('lacks', 12), ('lacked', 10)]
# revolutionize [('revolutionizing', 1), ('revolutionized', 1)]
# bustle [('bustling', 3)]
# diagnose [('diagnosed', 14), ('diagnose', 1)]
# decline [('declined', 70), ('declining', 20), ('decline', 12), ('declines', 5), ('Declining', 1)]
# infect [('infected', 4), ('infect', 3)]
# expande [('expanded.', 1)]
# inform [('informed', 31), ('inform', 7), ('informing', 4), ('informs', 1)]
# ...
# transit [('transits', 1)]
# deadlock [('deadlocked', 2)]
# standardize [('standardizing', 3), ('standardize', 1)]
# outstrip [('outstrips', 3), ('outstripping', 1), ('outstripped', 1)]
# harmonize [('harmonize', 1)]
# outperform [('outperform', 3), ('outperformed', 1)]
# industrialized [('industrialized', 1)]
# engineer [('engineered', 5), ('engineer', 3)]
# oxygenate [('oxygenated', 1)]
# circumvent [('circumvent', 2)]
# said [('saids', 1)]
# marginalize [('marginalized', 1)]
# congest [('congest', 1)]
# prepaid [('prepaid', 2)]
# videotape [('videotaped', 2), ('videotaping', 1)]
# elude [('eluded', 1)]
# straddle [('straddle', 1)]
# counteract [('counteract', 1)]
# slain [('slain', 1)]
# flout [('flouts', 1), ('flout', 1)]
# mediate [('mediating', 1), ('mediate', 1)]
# bludgeon [('bludgeoned', 1)]
# clinch [('clinching', 1)]
# mire [('mired', 4)]
# strick [('stricken', 2)]
# lunge [('lunge', 1)]
# pilfer [('pilfering', 1)]
# harrow [('harrowing', 1)]
# evict [('evicted', 1)]
# incubate [('incubate', 1)]
# estrange [('estranged', 3)]
# widow [('widowed', 1)]
# buoy [('buoyed', 2)]
# 0.473sec [('0.473sec', 1)]
# torment [('tormented', 1), ('torment', 1)]
# breakeven [('breakeven', 1)]
# hurtle [('hurtled', 1)]
# hatch [('hatched', 1)]
# siphon [('siphoned', 1)]
# Met [('Met', 1)]
# co-wrote [('co-wrote', 4)]
# promulgate [('promulgated', 2)]
# proposed [('proposed', 1)]
# scuttle [('scuttled', 1)]
# dwindle [('dwindled', 3), ('dwindling', 1)]
# enthral [('enthralled', 1)]
# foam [('foaming', 1)]
# demagogue [('demagoguing', 1)]
# modulate [('modulating', 1), ('modulated', 1)]
# pride [('prides', 1), ('pride', 1)]
# telecommute [('telecommuting', 1)]
# demonstate [('demonstates', 1)]
# revist [('revisted', 1)]
# reimagine [('reimagine', 1)]
# enliven [('enliven', 1)]
# surmise [('surmise', 1)]
# buff [('buffed', 1)]
# network [('network', 1)]
# foretold [('foretold', 1)]
# spar [('sparred', 1), ('spar', 1)]
# tower [('towering', 2), ('Towering', 1)]
# dissimulate [('dissimulating', 1)]
# fuse [('fused', 3)]
# disbelieve [('disbelieving', 1)]
# father [('fathered', 1)]
# endue [('endued', 1)]
# impregnate [('impregnated', 1)]
# merit [('merit', 2)]
# hone [('honed', 2), ('honing', 1)]
# systematize [('systematize', 1)]
# intrigue [('intrigued', 2)]
# exalt [('exalted', 1)]
# jolt [('jolted', 4), ('jolt', 2), ('jolts', 1)]
# blurred [('blurred', 1)]
# slither [('slithering', 2)]
# writhe [('writhe', 1), ('writhing', 1)]
# discolor [('discolored', 1)]
# fondle [('fondles', 1)]
# boffow [('boffows', 1)]
# unburden [('unburdened', 1), ('unburdening', 1)]
# scandal-ize [('scandal-ize', 1)]
# convoke [('convoke', 1)]
# Betrayed [('Betrayed', 1)]
# gettte [('gettting', 1)]
# perch [('perched', 2)]
# char [('charred', 1)]
# mushroom [('mushroom', 1)]
# shimmer [('shimmers', 1), ('shimmering', 1), ('shimmered', 1)]
# reenter [('reenter', 1)]
# beseech [('beseeching', 1)]
# blindfold [('blindfolded', 1)]
# etch [('etched', 1)]
# graft [('grafted', 1)]
# well [('welled', 1)]
# intone [('intoned', 1), ('intones', 1)]
# perplex [('perplexed', 1)]
# giggle [('giggled', 2)]
# shadow [('shadowed', 1), ('shadow', 1)]
# ruble [('Ruble', 1)]
# titter [('tittering', 1)]
# mistranslate [('mistranslated', 1)]
# coruscate [('coruscating', 1)]
# induct [('inducted', 6), ('Inducted', 1)]
# co-write [('co-written', 6), ('co-writing', 1)]
# co-starr [('co-starred', 7)]
# dissatisfy [('Dissatisfied', 2)]
# major [('majoring', 1)]
# slim [('slimmed', 1)]
# narrate [('narrated', 5)]
# rekindle [('rekindle', 1), ('rekindled', 1)]
# Talkin [('Talkin', 1)]
# followe [('followed.', 1)]
# match. [('match.', 1)]
# self-harm [('self-harm', 1)]
# bartend [('bartending', 2)]
# ’write [('’Write', 1)]
# reprise [('reprised', 4)]
# masquerade [('masquerading', 1), ('masquerades', 1)]
# forego [('forego', 1)]
# characterise [('characterised', 2), ('Characterised', 1)]
# intoxicate [('intoxicated', 1)]
# debute [('debuted', 14)]
# ’try [('’try', 1)]
# acclaim [('acclaimed', 7)]
# spurned [('spurned', 1)]
# spawn [('spawned', 4), ('spawning', 2), ('spawn', 1)]
# resonate [('resonates', 1)]
# flatpick [('flatpicks', 1)]
# anaesthetise [('anaesthetised', 1)]
# voice-act [('voice-acted', 1)]
# animate [('animated', 10)]
# gimme [('Gimme', 1)]
# co-produce [('co-produced', 5), ('co-producing', 2), ('Co-produced', 1)]
# kick-start [('kick-started', 1)]
# quip [('quipped', 1), ('quips', 1)]
# co-starring [('Co-starring', 1)]
# whoop [('whooped', 1)]
# overdose [('overdosed', 1)]
# ’keep [('’Keep', 1)]
# taunt [('taunted', 1)]
# miscarry [('miscarried', 1)]
# mime [('mimed', 1), ('miming', 1)]
# outfit [('outfitted', 1)]
# re-sign [('re-signed', 2)]
# reestablish [('reestablish', 2), ('reestablished', 1)]
# segue [('segued', 1)]
# eschew [('eschewed', 1)]
# predate [('predate', 1), ('predated', 1)]
# swashbuckle [('swashbuckling', 1)]
# brighten [('brightened', 2)]
# grossing [('grossing', 1)]
# ador [('adored', 1)]
# duet [('duetted', 1), ('duetting', 1)]
# chide [('chided', 1)]
# re-style [('re-styled', 1)]
# affecte [('affected.', 1)]
# heckle [('heckled', 2)]
# impart [('impart', 1)]
# premiere [('premiered', 4)]
# reissue [('reissued', 3)]
# demo [('demoed', 1)]
# graze [('grazed', 1)]
# baptise [('baptised', 1)]
# emphasise [('emphasise', 1)]
# nourish [('nourished', 1)]
# ’finish [('’finished', 1)]
# jar [('jarring', 1)]
# heard” [('heard”.', 1)]
# pen [('penned', 2), ('penning', 1)]
# barnstorm [('barnstorming', 1)]
# co-found [('co-founded', 3)]
# première [('premièred', 1)]
# remix [('remixed', 3)]
# rationalise [('rationalising', 1)]
# faile [('failed.', 1)]
# sing. [('sang.', 1)]
# immerse [('immersed', 1)]
# flatter [('flattered', 1)]
# sprain [('sprained', 1)]
# epitomize [('epitomize', 1)]
# summarise [('summarised', 1)]
# gang [('gang', 1)]
# blowin [('Blowin', 4)]
# chart [('chart', 4), ('charting', 4), ('charted', 2)]
# Protect [('Protect', 1)]
# sell. [('sell.', 1)]
# rename [('renamed', 4)]
# re-record [('re-recorded', 4)]
# mother [('mothered', 1)]
# spoof [('spoofed', 1)]
# crazed. [('crazed.', 1)]
# ’deranged’. [('’deranged’.', 1)]
# say”. [('Say”.', 2)]
# begin”. [('Begin”.', 1)]
# audition [('auditioned', 1), ('audition', 1)]
# punctuate [('punctuated', 2)]
# airball [('airballed', 1)]
# co-adapt [('co-adapted', 1)]
# guest-host [('guest-hosted', 1)]
# rehire [('rehired', 2)]
# elope [('eloped', 1)]
# dim [('dimmed', 1), ('dim', 1)]
# frequent [('frequent', 2), ('frequented', 1)]
# patronize [('patronizing', 1), ('patronized', 1)]
# teenaged [('teenaged', 1)]
# pulsate [('pulsating', 1)]
# Bring [('Bring', 1)]
# desist [('desist', 1)]
# accentuate [('accentuated', 1)]
# ting [('tinged', 1)]
# shook [('Shook', 1)]
# mimic [('mimicking', 1), ('mimicked', 1), ('mimic', 1)]
# supplement [('supplemented', 1)]
# owing [('owing', 1)]
# revitalise [('revitalise', 1)]
# pair [('paired', 4), ('pairing', 1)]
# liken [('likened', 1)]
# Takes [('Takes', 1)]
# engender [('engendered', 1)]
# get”. [('get”.', 1)]
# a-changin [('a-Changin', 1)]
# fever [('fevered', 1)]
# ’fuck [('’fucking', 1)]
# skywrite [('Skywriting', 1)]
# transcend [('transcend', 1)]
# says [('says.', 1)]
# jeer [('jeered', 1)]
# handclap [('handclapped', 1)]
# harken [('harkening', 1)]
# Fell [('Fell', 3)]
# sculpt [('sculpted', 1)]
# deplore [('deplore', 1)]
# coalesce [('coalesced', 1)]
# davis-continue [('Davis-continued', 1)]
# stupefy [('stupefied', 1)]
# me”/”ask [('Me”/”Ask', 1)]
# prefigure [('prefigured', 2)]
# burnette-form [('Burnette-formed', 1)]
# co-written [('co-written', 1)]
# satirise [('Satirising', 1)]
# Strike [('Strike', 1)]
# understand. [('understand.', 1)]
# rasp [('rasping', 1)]
# inspired [('inspired', 1)]
# recovere [('recovered.', 1)]
# miff [('miffed', 1)]
# hit. [('hit.', 1)]
# waltz [('Waltz', 1)]
# you”-were [('You”-were', 1)]
# startle [('startled', 1)]
# enrage [('enraged', 1)]
# acting [('acting', 1)]
# be”. [('Be”.', 1)]
# please. [('please.', 1)]
# discomfort [('discomforted', 1)]
# person”. [('person”.', 1)]
# chronicle [('chronicles', 1), ('chronicled', 1)]
# room [('rooming', 1)]
# trundle [('trundled', 1)]
# thaw [('thawed', 1)]
# consummated [('consummated.', 1)]
# idolize [('idolizing', 1)]
# symbolise [('symbolise', 1), ('symbolised', 1)]
# whittle [('whittled', 1)]
# disengage [('disengaged', 1)]
# catapult [('catapulting', 1)]
# rerelease [('rereleased', 1)]
# unsettle [('unsettled', 1)]
# received [('received.', 1)]
# happy”. [('happy”.', 1)]
# dismay [('dismayed', 5)]
# popularise [('popularised', 1)]
# Plant [('Plant', 1)]
# muddy [('muddying', 1)]
# Records [('Records', 1)]
# happens. [('happens.', 1)]
# choreograph [('Choreographed', 1)]
# photograph/film [('photograph/film', 1)]
# w [('wed', 1)]
# confide [('confided', 1)]
# harmonised [('harmonised', 1)]
# oscillate [('oscillating', 1)]
# emaciated [('emaciated', 1)]
# overproduce [('overproduced', 1)]
# waylay [('waylay', 1)]
# co-own [('co-owned', 1)]
# mold [('molded', 1)]
# fingerpicking [('fingerpicking', 1)]
# gaze [('gaze', 1)]
# parody [('parodied', 1)]
# boo [('booing', 1)]
# costarre [('costarring', 2)]
# cremate [('cremated', 1)]
# capitulate [('capitulated', 1)]
# immortalise [('immortalised', 1)]
# precedent [('precedented', 1)]
# polarise [('polarised', 1)]
# centr [('centred', 1)]
# energize [('energized', 1)]
# curate [('curate', 1)]
# publicise [('publicised', 1)]
# Serve [('Serve', 1)]
# Save [('Save', 1)]
# evince [('evinced', 1)]
# greenlight [('greenlight', 1)]
# Slept [('Slept', 1)]
# evangelize [('evangelize', 1)]
# personalize [('personalized', 2)]
# optimize [('optimized', 1)]
# remit [('remitted', 1), ('remitting', 1)]
# trustee [('trustee', 1)]
# depreciate [('depreciate', 1)]
# actualize [('actualized', 1)]
# diverge [('diverging', 1)]
# liven [('liven', 1)]
# camouflage [('camouflaged', 2)]
# smuggling [('smuggling', 1)]
# synchronize [('synchronized', 1)]
# arbitrate [('arbitrating', 1)]
# re-organize [('re-organize', 2)]
# pacify [('pacify', 1)]
# crane [('craning', 1)]
# requisition [('requisitioned', 1)]
# blot [('blotting', 1)]
# frolic [('frolic', 1)]
# clobber [('clobbered', 2)]
# buffer [('buffer', 1)]
# undo [('undo', 1)]
# reformulate [('reformulated', 1)]
# burnish [('burnishing', 1)]
# unchlorinate [('unchlorinated', 1)]
# bidding [('bidding', 1)]
# tender [('tender', 3), ('tendered', 1)]
# grumble [('grumble', 1)]
# enjoin [('enjoined', 2)]
# SWUNG [('SWUNG', 1)]
# weakening [('weakening', 2)]
# pre-register [('pre-register', 1)]
# outdo [('outdone', 1)]
# countervail [('countervailing', 1)]
# whipsaw [('whipsawed', 1)]
# underwrite [('underwritten', 5), ('underwrite', 1)]
# boean [('borne', 1)]
# sap [('sapped', 1), ('sapping', 1)]
# pre-try [('pre-try', 1)]
# bud [('budding', 1)]
# incline [('inclined', 3)]
# ruffle [('ruffled', 1)]
# underwhelm [('underwhelmed', 1)]
# blunder [('blundered', 1)]
# brave [('braving', 1)]
# Hoe [('Hoe', 1)]
# reappraise [('reappraised', 1), ('reappraise', 1)]
# cushion [('cushioning', 1)]
# flinch [('flinch', 1)]
# veile [('Veiling', 1)]
# stuck [('stuck', 1)]
# roil [('roiling', 1)]
# inch [('inching', 1)]
# subordinate [('subordinated', 5), ('subordinate', 1)]
# delegate [('delegate', 2)]
# dispense [('dispense', 1), ('dispensed', 1)]
# jettison [('jettisoning', 1)]
# undervalue [('undervalued', 2)]
# wove [('woven', 1)]
# toast [('toasted', 1)]
# outshine [('outshine', 1)]
# pinhead [('pinheaded', 1)]
# nonrecurr [('nonrecurring', 1)]
# misstate [('misstated', 4)]
# liquefy [('liquefy', 2), ('liquefies', 1)]
# ooze [('oozing', 1)]
# quiet [('quieted', 1)]
# co-manage [('co-managing', 1)]
# dangle [('dangling', 1)]
# idle [('idle', 4), ('idled', 2)]
# traumatize [('traumatized', 1)]
# overcommit [('overcommitted', 1)]
# founder [('foundered', 1)]
# underpin [('underpinned', 2)]
# nonoperate [('nonoperating', 1)]
# charter [('chartered', 1)]
# steady [('steadied', 1)]
# piggyback [('Piggybacking', 1)]
# interested [('interested', 1)]
# captivate [('captivating', 1)]
# oversubscribe [('oversubscribed', 2)]
# canvass [('canvassed', 1)]
# sweeten [('sweetened', 2), ('sweeten', 2)]
# filch [('filched', 1)]
# reset [('reset', 2)]
# bulldoze [('bulldozed', 1)]
# staple [('stapling', 1)]
# unroll [('unrolls', 1)]
# subsume [('subsumed', 1)]
# hemorrhage [('hemorrhaged', 1)]
# decertify [('decertified', 1)]
# launder [('laundering', 1), ('launder', 1)]
# accrue [('accrue', 2)]
# rat [('rat', 1)]
# connected [('connected', 1)]
# scandalize [('scandalized', 1)]
# humble [('humbled', 1)]
# nurse [('nursing', 1)]
# battl [('BATTLED', 1)]
# stipple [('stippled', 1)]
# damp [('damp', 1)]
# handpick [('handpicked', 1)]
# muse [('muses', 2)]
# tone [('toned', 1)]
# detach [('Detached', 1)]
# mass-produce [('mass-producing', 1)]
# scoff [('scoffs', 1)]
# spurt [('spurted', 1)]
# reverberate [('reverberating', 2)]
# reinstitute [('reinstituting', 1)]
# televised [('televised', 1)]
# pyramide [('pyramiding', 1)]
# demote [('demoted', 1)]
# empathize [('empathize', 1)]
# fumper [('fumpered', 1)]
# schmumper [('schmumpered', 1)]
# glide [('gliding', 1)]
# overcrowd [('overcrowded', 1)]
# reoffer [('reoffered', 2)]
# rivale [('rivaling', 1)]
# electrify [('electrified', 1)]
# appal [('appalled', 2)]
# restyled [('restyled', 1)]
# scrounge [('scrounged', 1), ('scrounge', 1)]
# reinvest [('reinvest', 1), ('reinvested', 1)]
# itemize [('itemize', 1), ('itemized', 1)]
# legitimize [('legitimized', 1), ('legitimize', 1)]
# grimace [('grimace', 1)]
# undulate [('undulate', 1)]
# merchandising [('merchandising', 1)]
# nonperform [('nonperforming', 2)]
# buckle [('buckle', 1)]
# reassume [('reassume', 1)]
# diminished [('diminished', 1)]
# row [('rowed', 1)]
# recraft [('recraft', 1)]
# exorcise [('exorcise', 1)]
# reinstall [('reinstalled', 1)]
# selected [('selected', 1)]
# auction [('auctioned', 2), ('auction', 1)]
# bumble [('bumble', 1)]
# dispel [('dispelled', 1)]
# snowball [('snowballed', 1)]
# discomfit [('discomfited', 1)]
# glut [('glut', 1)]
# corral [('corral', 1)]
# renegotiate [('renegotiating', 1)]
# resell [('reselling', 1), ('resell', 1)]
# swerve [('swerve', 1)]
# color-code [('color-coded', 1)]
# gird [('girding', 1)]
# loiter [('loitering', 1)]
# handicap [('handicapped', 1)]
# redesign [('redesign', 1)]
# added [('added', 1)]
# romance [('romancing', 1)]
# repossess [('repossessed', 1)]
# smother [('smother', 1)]
# spurn [('spurning', 1), ('spurned', 1)]
# mechanize [('mechanized', 1)]
# snort [('snorts', 1)]
# redraw [('redraw', 1)]
# fertilize [('fertilized', 1)]
# pollinate [('pollinate', 1)]
# cross-pollinate [('cross-pollinated', 1)]
# pony [('ponied', 1)]
# double-cross [('double-crossed', 1)]
# savor [('savored', 1)]
# squint [('squinted', 1)]
# streak [('streaked', 1)]
# rear [('rearing', 1)]
# civilized [('Civilized', 1)]
# clad [('Clad', 1)]
# losing [('losing', 1)]
# liquidate [('liquidated', 2), ('liquidating', 1)]
# sizzling [('sizzling', 1)]
# elected [('elected', 1)]
# appointed [('appointed', 1)]
# re-supply [('re-supplied', 1)]
# specialized [('specialized', 1)]
# drumbeating [('drumbeating', 1)]
# fog [('fog', 1)]
# fatten [('fatten', 1), ('fattened', 1)]
# stroke [('Stroking', 1)]
# democratize [('democratized', 1)]
# debut [('debut', 1)]
# establsh [('establshed', 1)]
# ferret [('ferret', 1)]
# overriding [('overriding', 1)]
# propagandize [('propagandize', 1)]
# transcribe [('transcribe', 1)]
# sputter [('sputtered', 1)]
# intention [('intentioned', 1)]
# trespass [('trespass', 1)]
# secede [('secede', 1)]
# gyrate [('gyrate', 1)]
# overvalue [('overvalued', 1)]
# puzzle [('puzzled', 1)]
# shor [('shoring', 1)]
# tamper [('tampering', 1)]
# budge [('budged', 1), ('budge', 1)]
# crater [('cratering', 1)]
# repurchase [('repurchase', 2)]
# smolder [('smoldering', 1)]
# refinance [('refinance', 1)]
# spook [('spooked', 1)]
# militate [('militate', 1)]
# traduce [('traduced', 1)]
# semifinish [('semifinished', 1)]
# assuage [('assuage', 1)]
# snag [('snagged', 1)]
# cohere [('cohere', 1)]
# foment [('fomenting', 1)]
# peal [('pealing', 1)]
# mollify [('mollified', 1)]
# segment [('segmenting', 1)]
# beget [('begot', 1)]
# outrank [('outranks', 1)]
# telegraph [('telegraph', 1)]
# expunge [('expunged', 1)]
# dull [('dulled', 1)]
# unnerve [('unnerved', 1)]
# committed [('committed', 1)]
# tether [('tethered', 1)]
# stud [('studded', 1)]
# carp [('carp', 1)]
# overb [('overbid', 1)]
# scribble [('scribbled', 1)]
# Spill [('Spill', 1)]
# theres [('Theres', 1)]
# wasen [('wasent', 1)]
# luv [('Luv', 1)]
# licensed [('licensed', 1)]
# mingle [('mingle', 1)]
# reffer [('reffered', 1)]
# new [('new', 1)]
# isn’t [('isn’ta', 1)]
# appologize [('appologized', 1)]
# relax. [('relax.', 1)]
# overcharge [('overcharge', 1), ('overcharged', 1)]
# spay [('spayed', 1)]
# nestle [('nestled', 1)]
# nibble [('nibble', 1)]
# loss [('loss', 1)]
# re-train [('re-trained', 1)]
# obligated [('obligated', 1)]
# renig [('renigged', 1)]
# embroider [('embroidered', 1)]
# mindblowing [('mindblowing', 1)]
# begiin [('begiinning', 1)]
# serve/cook [('serve/cook', 1)]
# branch [('Branch', 1)]

# %%
verb_lemma = 'be'
org = 'is'
cid_index = 1

# %%
def view_parse(verb_lemma, org, cid_index):
    dataset, cid = verb_lemma2org2dataset_cids[verb_lemma][org][cid_index]
    for framework, dataset2mrp_jsons in framework2dataset2mrp_jsons.items():
        if dataset in dataset2mrp_jsons:
            logger.info(pprint.pformat(dataset2mrp_jsons[dataset][cid_index]))
            graphviz_file_name = dataset2mrp_jsons[dataset][cid_index].get('id')
            if graphviz_file_name:
                logger.info((framework, dataset, graphviz_file_name))
                logger.info(args.graphviz_file_template.format(framework, dataset, graphviz_file_name))
    return dataset2cid2parse[dataset][cid]

# %%
dataset
# Out:
# 'ewt'

# %%
dataset
# Out:
# 'ewt'

# %%
view_parse(verb_lemma, org, cid_index)
# Out:
# INFO:__main__:{'edges': [{'label': 'degree', 'source': 0, 'target': 4},
#            {'label': 'ARG2', 'source': 0, 'target': 1},
#            {'label': 'path', 'source': 1, 'target': 3},
#            {'label': 'destination', 'source': 1, 'target': 2}],
#  'flavor': 2,
#  'framework': 'amr',
#  'id': 'bc.cctv_0000.167',
#  'input': "It 's extremely troublesome to get there via land .",
#  'nodes': [{'id': 0, 'label': 'trouble-05'},
#            {'id': 1, 'label': 'get-05'},
#            {'id': 2, 'label': 'there'},
#            {'id': 3, 'label': 'land'},
#            {'id': 4, 'label': 'extreme'}],
#  'time': '2019-04-10 (20:10)',
#  'tops': [0],
#  'version': 0.9}
# INFO:__main__:('amr', 'amr-guidelines', 'bc.cctv_0000.167')
# INFO:__main__:http://localhost:8000/files/proj29_ds1/home/slai/mrp/graphviz/amr/amr-guidelines.mrp/bc.cctv_0000.167.png
# [['1',
#   'There',
#   'there',
#   'PRON',
#   'EX',
#   '_',
#   '2',
#   'expl',
#   '_',
#   'TokenRange=0:5'],
#  ['2', 'is', 'be', 'VERB', 'VBZ', '_', '0', 'root', '_', 'TokenRange=6:8'],
#  ['3', 'no', 'no', 'DET', 'DT', '_', '4', 'det', '_', 'TokenRange=9:11'],
#  ['4',
#   'possibility',
#   'possibility',
#   'NOUN',
#   'NN',
#   '_',
#   '2',
#   'nsubj',
#   '_',
#   'TokenRange=12:23'],
#  ['5',
#   'that',
#   'that',
#   'SCONJ',
#   'IN',
#   '_',
#   '9',
#   'mark',
#   '_',
#   'TokenRange=24:28'],
#  ['6', 'the', 'the', 'DET', 'DT', '_', '7', 'det', '_', 'TokenRange=29:32'],
#  ['7', 'boy', 'boy', 'NOUN', 'NN', '_', '9', 'nsubj', '_', 'TokenRange=33:36'],
#  ['8', 'will', 'will', 'AUX', 'MD', '_', '9', 'aux', '_', 'TokenRange=37:41'],
#  ['9', 'go', 'go', 'VERB', 'VB', '_', '4', 'ccomp', '_', 'TokenRange=42:44'],
#  ['10', '.', '.', 'PUNCT', '.', '_', '2', 'punct', '_', 'TokenRange=44:45']]
